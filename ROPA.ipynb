# %% [markdown]
# <a href="https://colab.research.google.com/github/flohaha/Colab_Better_Rop/blob/main/ROPA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install google
#!pip install google-api-core
#!pip install google-colab
#!pip install gspread
#!pip install gsheet_pandas

# %%
# !pip install gsheet_pandas
# Out:
# Requirement already satisfied: gsheet_pandas in /usr/local/lib/python3.10/dist-packages (0.2.8)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.101.0 in /usr/local/lib/python3.10/dist-packages (from gsheet_pandas) (2.123.0)
# Requirement already satisfied: google-auth-httplib2<0.2.0,>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from gsheet_pandas) (0.1.1)
# Requirement already satisfied: google-auth-oauthlib<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from gsheet_pandas) (1.2.0)
# Requirement already satisfied: pandas<3.0.0,>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from gsheet_pandas) (2.2.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gsheet_pandas) (1.0.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2.0.0,>=1.1.0->gsheet_pandas) (1.3.1)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.1->gsheet_pandas) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.1->gsheet_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.1->gsheet_pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.1->gsheet_pandas) (2024.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (1.63.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (3.20.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.1->gsheet_pandas) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2.0.0,>=1.1.0->gsheet_pandas) (3.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client<3.0.0,>=2.101.0->gsheet_pandas) (2024.6.2)

# %%
import gspread

# %%
 try:
    from google.colab import drive
    drive.mount('/content/drive')
    #!ls -l /content/drive/'My Drive/PRO/BetterStronger/ROPA'
except:
    print('couldnt connect')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#from google.colab import auth
#auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
try:
    from google.colab import auth
    auth.authenticate_user()

    from oauth2client.client import GoogleCredentials

except:
    print('couldnt connect')

# %%
SS_Link = 'https://docs.google.com/spreadsheets/d/1I8iMjqpszFhEFdcpJIR8DI-kIwNmROqnHuk6cNoXPgs/edit#gid=1574651002'

### new copie 'https://docs.google.com/spreadsheets/d/1I8iMjqpszFhEFdcpJIR8DI-kIwNmROqnHuk6cNoXPgs/edit#gid=1574651002'
### old test 'https://docs.google.com/spreadsheets/d/18kI721X-bXSx-nnOjzGuPM62buTsfiMsEDc7sEIciWI/edit#gid=957651562'

# %%
import pandas as pd
# read data and put it in a dataframe
gsheets = gc.open_by_url(SS_Link)
sheets = gsheets.worksheet('ROPA - Data Infos').get_all_values()
df_infos = pd.DataFrame(sheets[1:], columns=sheets[0])

df_infos
# Out:
#                                   Acquisition  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2
# 3
# 4
# ..                                        ...
# 250
# 251
# 252
# 253
# 254                                   Acpm.fr
#
#                                                         \
# 0                                          Description
# 1    Data visualization tool: creating interactive ...
# 2
# 3
# 4
# ..                                                 ...
# 250
# 251
# 252
# 253
# 254  ACPM (The Alliance for Print and Media Data) i...
#
#                                                                            \
# 0    Internal or Third Party  Internal Team  Owners/Stakeholders/Contacts
# 1                       3rdP     Technology         Prasannaa Subramanian
# 2
# 3
# 4
# ..                       ...            ...                           ...
# 250
# 251
# 252
# 253
# 254                               Marketing
#
#                                                    \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2
# 3
# 4
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254
#
#                                                       \
# 0    Connection type between the source and the tool
# 1                                  Native connection
# 2
# 3
# 4
# ..                                               ...
# 250
# 251
# 252
# 253
# 254
#
#                                                         \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2
# 3
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251
# 252
# 253
# 254
#
#                                          \
# 0               Data Collection Methods
# 1    Collected directly from Databricks
# 2
# 3
# 4
# ..                                  ...
# 250
# 251
# 252
# 253
# 254
#
#                                                 ...  \
# 0    Data Collection adapted to user consent?   ...
# 1                                            Y  ...
# 2                                               ...
# 3                                               ...
# 4                                               ...
# ..                                         ...  ...
# 250                                             ...
# 251                                             ...
# 252                                             ...
# 253                                             ...
# 254                                             ...
#
#                                            \
# 0    Data shared overseas -\nY, where | N
# 1                                     N/A
# 2
# 3
# 4
# ..                                    ...
# 250
# 251
# 252
# 253
# 254
#
#                                           \
# 0    Data encryption or pseudonymisation
# 1                                    N/A
# 2
# 3
# 4
# ..                                   ...
# 250
# 251
# 252
# 253
# 254
#
#                                   Retention & Disposal  \
# 0    Duration for which the data is required to rem...
# 1       2 years (mostly)  - It can be 4 but never more
# 2
# 3
# 4
# ..                                                 ...
# 250
# 251
# 252
# 253
# 254
#
#                                                      \
# 0       Duration for which the data is retained\n\n
# 1    2 years (mostly)  - It can be 4 but never more
# 2
# 3
# 4
# ..                                              ...
# 250
# 251
# 252
# 253
# 254
#
#                                                         \
# 0    Policies and processes for retaining and delet...
# 1                                                    Y
# 2
# 3
# 4
# ..                                                 ...
# 250
# 251
# 252
# 253
# 254
#
#                                                                      Access  \
# 0    Methods to ensure that deleted data is removed...  Doc shared with B&S
# 1    Only on the plateform, not on Databricks\n\nAu...                    Y
# 2
# 3
# 4
# ..                                                 ...                  ...
# 250
# 251
# 252
# 253
# 254
#
#
# 0
# 1
# 2
# 3
# 4
# ..  .. .. ..
# 250
# 251
# 252
# 253
# 254
#
# [255 rows x 36 columns]

# %%
# col_names = df_infos.iloc[1:3, :]

# df_infos.reset_index(drop=True, inplace=True)

df_infos.iloc[0, :]

#df_infos.columns #= df_infos.iloc[0:1, :]
# Out:
# Acquisition                      The name of the tool / provider / system
#                                                               Description
#                                                   Internal or Third Party
#                                                             Internal Team
#                                              Owners/Stakeholders/Contacts
#                              Source(s) from which the tool retrieves data
#                           Connection type between the source and the tool
#                         Data Categories gathered from the source(s) \n...
#                                                   Data Collection Methods
#                                 Data Collection adapted to user consent?
#                         Tracker? (network calls from users to the syst...
# Processing                                                  Data Purposes
#                                                                 Data Uses
#                                                  Data processed for VF FR
#                         ePrivacy Application: Are there network calls ...
# Storage                 What system do we store that data in (when it ...
#                                          Who is the third party provider?
#                         What jurisdiction / geographic region is this ...
#                         Restrictions / Limitations concerning the stor...
#                                        Technical Organisational Measures
# Sharing                               Data shared with other CN entities?
#                                                        If yes, which ones
#                                  Data shared with another tool / system ?
#                                                 If yes, which recipients?
#                                                  Purpose for sharing data
#                                                           Sharing methods
#                                      Data shared overseas -\nY, where | N
#                                       Data encryption or pseudonymisation
# Retention & Disposal    Duration for which the data is required to rem...
#                               Duration for which the data is retained\n\n
#                         Policies and processes for retaining and delet...
#                         Methods to ensure that deleted data is removed...
# Access                                                Doc shared with B&S
#
#
#
# Name: 0, dtype: object

# %%
len(df_infos)
# Out:
# 255

# %%
df_infos.iloc[:, 0].unique().tolist()
# Out:
# ['The name of the tool / provider / system',
#  'Qlik + Dash',
#  '',
#  'Falcon',
#  'ContentIQ',
#  'AdmantX',
#  'Snowplow',
#  '4D',
#  'Permutive\n(Commercial name for CondeNast: Spire)',
#  'Obsidian',
#  'Sparrow',
#  'Copilot',
#  'Encore',
#  'Content API / Content Service',
#  'Verso',
#  'Databricks',
#  'Mode',
#  'Alation (Cosmos)',
#  'Avo',
#  'Piwik Pro',
#  'Google Analytics UA',
#  'Google Analytics 4                                                                                                                                                                                                                                     ',
#  'Google Tag Manager',
#  'Treasure Data',
#  'OneTrust',
#  'xid (infinity id)',
#  'Parse.ly',
#  'Fastly\n(replaced by CloudFront in April 3, 2024)\n',
#  'dbt Labs',
#  'Datadog',
#  'Polyfill.io',
#  'Boomerang',
#  'GLI',
#  'Prebid Partners (Magnite, Xandr, PubMatic, Criteo)',
#  'TAM / UAM',
#  'OB/Tag',
#  'AWS',
#  'FiveTran',
#  'Skimlinks (Taboola Company)',
#  'CNE',
#  'Youtube',
#  'Sailthru',
#  'Adomik',
#  'Recommendation Models (most popular articles)',
#  'Recommendation Models (similar articles)',
#  'Dash Hudson / Social Flow',
#  'Google Ad Manager',
#  'Acpm.fr']

# %%
for i in range(0,len(df_infos)):
  for c in range(0,len(df_infos.columns)):
    z = df_infos.iloc[i, c]
    if z == '':
      df_infos.iloc[i, c] = df_infos.iloc[i-1, c]

df_infos#.iloc[:, 0].unique().tolist()
# Out:
#                                   Acquisition  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                                         \
# 0                                          Description
# 1    Data visualization tool: creating interactive ...
# 2    Data visualization tool: creating interactive ...
# 3    Data visualization tool: creating interactive ...
# 4    Data visualization tool: creating interactive ...
# ..                                                 ...
# 250  GAM is a software owned by Google used by CN f...
# 251  GAM is a software owned by Google used by CN f...
# 252  GAM is a software owned by Google used by CN f...
# 253  GAM is a software owned by Google used by CN f...
# 254  ACPM (The Alliance for Print and Media Data) i...
#
#                                              \
# 0    Internal or Third Party  Internal Team
# 1                       3rdP     Technology
# 2                       3rdP     Technology
# 3                       3rdP     Technology
# 4                       3rdP     Technology
# ..                       ...            ...
# 250                       3P     Technology
# 251                       3P     Technology
# 252                       3P     Technology
# 253                       3P     Technology
# 254                       3P      Marketing
#
#                                                         \
# 0                         Owners/Stakeholders/Contacts
# 1                                Prasannaa Subramanian
# 2                                Prasannaa Subramanian
# 3                                Prasannaa Subramanian
# 4                                Prasannaa Subramanian
# ..                                                 ...
# 250  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 251  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 252  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 253  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 254  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
#
#                                                    \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                                       \
# 0    Connection type between the source and the tool
# 1                                  Native connection
# 2                                  Native connection
# 3                                  Native connection
# 4                                  Native connection
# ..                                               ...
# 250                                          GTM Tag
# 251                                          GTM Tag
# 252                                          GTM Tag
# 253                                          GTM Tag
# 254                                          GTM Tag
#
#                                                         \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                                                \
# 0                     Data Collection Methods
# 1          Collected directly from Databricks
# 2          Collected directly from Databricks
# 3          Collected directly from Databricks
# 4          Collected directly from Databricks
# ..                                        ...
# 250  Collected directly from Social Platforms
# 251  Collected directly from Social Platforms
# 252  Collected directly from Social Platforms
# 253  Collected directly from Social Platforms
# 254  Collected directly from Social Platforms
#
#                                                 ...  \
# 0    Data Collection adapted to user consent?   ...
# 1                                            Y  ...
# 2                                            Y  ...
# 3                                            Y  ...
# 4                                            Y  ...
# ..                                         ...  ...
# 250                                        Yes  ...
# 251                                        Yes  ...
# 252                                        Yes  ...
# 253                                        Yes  ...
# 254                                        Yes  ...
#
#                                            \
# 0    Data shared overseas -\nY, where | N
# 1                                     N/A
# 2                                     N/A
# 3                                     N/A
# 4                                     N/A
# ..                                    ...
# 250                                   N/A
# 251                                   N/A
# 252                                   N/A
# 253                                   N/A
# 254                                   N/A
#
#                                           \
# 0    Data encryption or pseudonymisation
# 1                                    N/A
# 2                                    N/A
# 3                                    N/A
# 4                                    N/A
# ..                                   ...
# 250                                  N/A
# 251                                  N/A
# 252                                  N/A
# 253                                  N/A
# 254                                  N/A
#
#                                   Retention & Disposal  \
# 0    Duration for which the data is required to rem...
# 1       2 years (mostly)  - It can be 4 but never more
# 2       2 years (mostly)  - It can be 4 but never more
# 3       2 years (mostly)  - It can be 4 but never more
# 4       2 years (mostly)  - It can be 4 but never more
# ..                                                 ...
# 250                                                N/A
# 251                                                N/A
# 252                                                N/A
# 253                                                N/A
# 254                                                N/A
#
#                                                      \
# 0       Duration for which the data is retained\n\n
# 1    2 years (mostly)  - It can be 4 but never more
# 2    2 years (mostly)  - It can be 4 but never more
# 3    2 years (mostly)  - It can be 4 but never more
# 4    2 years (mostly)  - It can be 4 but never more
# ..                                              ...
# 250                                             N/A
# 251                                             N/A
# 252                                             N/A
# 253                                             N/A
# 254                                             N/A
#
#                                                         \
# 0    Policies and processes for retaining and delet...
# 1                                                    Y
# 2                                                    Y
# 3                                                    Y
# 4                                                    Y
# ..                                                 ...
# 250                                                N/A
# 251                                                N/A
# 252                                                N/A
# 253                                                N/A
# 254                                                N/A
#
#                                                                      Access  \
# 0    Methods to ensure that deleted data is removed...  Doc shared with B&S
# 1    Only on the plateform, not on Databricks\n\nAu...                    Y
# 2    Only on the plateform, not on Databricks\n\nAu...                    Y
# 3    Only on the plateform, not on Databricks\n\nAu...                    Y
# 4    Only on the plateform, not on Databricks\n\nAu...                    Y
# ..                                                 ...                  ...
# 250                                                N/A                    N
# 251                                                N/A                    N
# 252                                                N/A                    N
# 253                                                N/A                    N
# 254                                                N/A                    N
#
#
# 0
# 1
# 2
# 3
# 4
# ..  .. ..  ...
# 250        N/A
# 251        N/A
# 252        N/A
# 253        N/A
# 254        N/A
#
# [255 rows x 36 columns]

# %%
df_sample = df_infos#[df_infos.iloc[:, 0] == 'System I']  ### TEST  >> [df_infos.iloc[:, 0] == 'System I']

df_sample = df_sample.iloc[:, [0,5,7,11,12]]#,14,19]]

df_sample
# Out:
#                                   Acquisition  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                                    \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                                         \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                                             Processing  \
# 0                                        Data Purposes
# 1        Personalisation of Ads, Content and Services
# 2           Optimization of Ads, Content and Services
# 3                                           Marketing
# 4                   Same as the previous data category
# ..                                                 ...
# 250  No data collected from Vanity Fair (France) us...
# 251  No data collected from Vanity Fair (France) us...
# 252  No data collected from Vanity Fair (France) us...
# 253  No data collected from Vanity Fair (France) us...
# 254  No data collected from Vanity Fair (France) us...
#
#
# 0                                            Data Uses
# 1    Content Personalisation: Tracking user prefere...
# 2    Personalised Ad Performance Optimization: Moni...
# 3    Subscription-Data Marketing: Enabling targeted...
# 4                   Same as the previous data category
# ..                                                 ...
# 250  No data collected from Vanity Fair (France) us...
# 251  No data collected from Vanity Fair (France) us...
# 252  No data collected from Vanity Fair (France) us...
# 253  No data collected from Vanity Fair (France) us...
# 254  No data collected from Vanity Fair (France) us...
#
# [255 rows x 5 columns]

# %%
df_sample.columns = ['System','Sources','Data_Category','Data_Purpose','Data_Uses']#,'','']

# %%
df_sample

for i in range(0,len(df_sample)):
  z = df_sample.iloc[i, 1]
  if z == '':
    df_sample.iloc[i, 1] = df_sample.iloc[i-1, 1]

df_sample#.iloc[:, 0].unique().tolist()
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                                           Data_Purpose  \
# 0                                        Data Purposes
# 1        Personalisation of Ads, Content and Services
# 2           Optimization of Ads, Content and Services
# 3                                           Marketing
# 4                   Same as the previous data category
# ..                                                 ...
# 250  No data collected from Vanity Fair (France) us...
# 251  No data collected from Vanity Fair (France) us...
# 252  No data collected from Vanity Fair (France) us...
# 253  No data collected from Vanity Fair (France) us...
# 254  No data collected from Vanity Fair (France) us...
#
#                                              Data_Uses
# 0                                            Data Uses
# 1    Content Personalisation: Tracking user prefere...
# 2    Personalised Ad Performance Optimization: Moni...
# 3    Subscription-Data Marketing: Enabling targeted...
# 4                   Same as the previous data category
# ..                                                 ...
# 250  No data collected from Vanity Fair (France) us...
# 251  No data collected from Vanity Fair (France) us...
# 252  No data collected from Vanity Fair (France) us...
# 253  No data collected from Vanity Fair (France) us...
# 254  No data collected from Vanity Fair (France) us...
#
# [255 rows x 5 columns]

# %%
df_sample_gp = df_sample.groupby(['System','Sources', 'Data_Category'])['Data_Purpose'].apply('||'.join).reset_index()

df_sample_gp
# Out:
#                 System                   Sources  \
# 0                   4D                 ContentIQ
# 1                   4D                  Snowplow
# 2                  AWS                Databricks
# 3              Acpm.fr   Facebook + other pixels
# 4              AdmantX                 ContentIQ
# ..                 ...                       ...
# 219              Verso                    Fastly
# 220              Verso  Website (Vanity Fair FR)
# 221            Youtube   Website (Vanity Fair FR
# 222           dbt Labs    Databricks (meta data)
# 223  xid (infinity id)                       N/A
#
#                                          Data_Category  \
# 0               All Content IQ post consent categories
# 1                 All Snowplow post consent categories
# 2                       All Databricks data categories
# 3                        All Permutive Data Categories
# 4                                     Content Metadata
# ..                                                 ...
# 219                                                TBC
# 220                                                TBC
# 221                      Enhanced privacy mode enabled
# 222  N/A - No user-level data is processed. Dbt Lab...
# 223                                   User Identifiers
#
#                                           Data_Purpose
# 0        Personalisation of Ads, Content and Services
# 1        Personalisation of Ads, Content and Services
# 2    Technical provision of a requested product or ...
# 3    No data collected from Vanity Fair (France) us...
# 4    Personalisation of Ads, Content and Services |...
# ..                                                 ...
# 219  Technical provision of a requested product or ...
# 220  Technical provision of a requested product or ...
# 221  Technical provision of a requested product or ...
# 222                                                N/A
# 223  Personalisation of Ads, Content and Services |...
#
# [224 rows x 4 columns]

# %%
df_sample_unique = df_sample[['System','Sources','Data_Category']].drop_duplicates()

df_sample_unique
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 4                                 Qlik + Dash
# 5                                 Qlik + Dash
# 6                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 4                                      Databricks
# 5                                      Databricks
# 6                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                          Data_Category
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# 5                         Advertising Performance Data
# 6                              Social Media Engagement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
# [224 rows x 3 columns]

# %%
df_merged = pd.merge(df_sample_unique, df_sample_gp, how='left', left_on=['System','Sources', 'Data_Category'], right_on=['System', 'Sources', 'Data_Category'] )

df_merged = pd.merge(df_merged, df_sample, how='left', left_on=['System','Sources', 'Data_Category'], right_on=['System','Sources', 'Data_Category'] )


#df_merged['System','Sources','Data_Category','Data_Purpose_y','Data_Uses']

df_merged = df_merged[['System','Sources','Data_Category','Data_Purpose_y','Data_Uses']]
df_merged
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                                         Data_Purpose_y  \
# 0                                        Data Purposes
# 1        Personalisation of Ads, Content and Services
# 2           Optimization of Ads, Content and Services
# 3                                           Marketing
# 4                   Same as the previous data category
# ..                                                 ...
# 250  No data collected from Vanity Fair (France) us...
# 251  No data collected from Vanity Fair (France) us...
# 252  No data collected from Vanity Fair (France) us...
# 253  No data collected from Vanity Fair (France) us...
# 254  No data collected from Vanity Fair (France) us...
#
#                                              Data_Uses
# 0                                            Data Uses
# 1    Content Personalisation: Tracking user prefere...
# 2    Personalised Ad Performance Optimization: Moni...
# 3    Subscription-Data Marketing: Enabling targeted...
# 4                   Same as the previous data category
# ..                                                 ...
# 250  No data collected from Vanity Fair (France) us...
# 251  No data collected from Vanity Fair (France) us...
# 252  No data collected from Vanity Fair (France) us...
# 253  No data collected from Vanity Fair (France) us...
# 254  No data collected from Vanity Fair (France) us...
#
# [255 rows x 5 columns]

# %%
df_merged.iloc[1,[2,3]]
# Out:
# Data_Category              User Browsing & Engagement Behaviour
# Data_Purpose_y    Personalisation of Ads, Content and Services
# Name: 1, dtype: object

# %%
df_merged_sample = df_merged

df_merged_sample['Data_Uses'] = df_merged_sample['Data_Uses'].apply(lambda x: x.replace("\n","||"))

df_merged_sample['Data_Uses'] = df_merged_sample['Data_Uses'].apply(lambda x: x.split('||'))
df_merged_sample['Data_Purpose_y'] = df_merged_sample['Data_Purpose_y'].apply(lambda x: x.split('||'))

df_merged_sample
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                                         Data_Purpose_y  \
# 0                                      [Data Purposes]
# 1      [Personalisation of Ads, Content and Services ]
# 2         [Optimization of Ads, Content and Services ]
# 3                                         [Marketing ]
# 4                 [Same as the previous data category]
# ..                                                 ...
# 250  [No data collected from Vanity Fair (France) u...
# 251  [No data collected from Vanity Fair (France) u...
# 252  [No data collected from Vanity Fair (France) u...
# 253  [No data collected from Vanity Fair (France) u...
# 254  [No data collected from Vanity Fair (France) u...
#
#                                              Data_Uses
# 0                                          [Data Uses]
# 1    [Content Personalisation: Tracking user prefer...
# 2    [Personalised Ad Performance Optimization: Mon...
# 3    [Subscription-Data Marketing: Enabling targete...
# 4                 [Same as the previous data category]
# ..                                                 ...
# 250  [No data collected from Vanity Fair (France) u...
# 251  [No data collected from Vanity Fair (France) u...
# 252  [No data collected from Vanity Fair (France) u...
# 253  [No data collected from Vanity Fair (France) u...
# 254  [No data collected from Vanity Fair (France) u...
#
# [255 rows x 5 columns]

# %%
def product(*args):
    if not args:
        return iter(((),)) # yield tuple()
    return (items + (item,)
            for items in product(*args[:-1]) for item in args[-1])

list(product([1,2,3], ['a','b']))
# Out:
# [(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b'), (3, 'a'), (3, 'b')]

# %%
import itertools

somelists = [['aaz','bbz'],['ccz','ddz']]

list(itertools.product(['aa','bb'],['cc','dd']))
# Out:
# [('aa', 'cc'), ('aa', 'dd'), ('bb', 'cc'), ('bb', 'dd')]

# %%
df_merged_sample_zip = df_merged_sample

df_merged_sample_zip['zip'] = df_merged_sample_zip.apply(lambda x: list(product(x['Data_Purpose_y'], list(x['Data_Uses']))), axis=1)

df_merged_sample_zip = df_merged_sample_zip[['System','Sources','Data_Category','zip']]

df_merged_sample_zip
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                                                    zip
# 0                         [(Data Purposes, Data Uses)]
# 1    [(Personalisation of Ads, Content and Services...
# 2    [(Optimization of Ads, Content and Services , ...
# 3    [(Marketing , Subscription-Data Marketing: Ena...
# 4    [(Same as the previous data category, Same as ...
# ..                                                 ...
# 250  [(No data collected from Vanity Fair (France) ...
# 251  [(No data collected from Vanity Fair (France) ...
# 252  [(No data collected from Vanity Fair (France) ...
# 253  [(No data collected from Vanity Fair (France) ...
# 254  [(No data collected from Vanity Fair (France) ...
#
# [255 rows x 4 columns]

# %%
df_merged_sample_zip['join_trick'] = ''
df_merged_sample_zip
# Out:
# <ipython-input-29-b6fd350c56c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merged_sample_zip['join_trick'] = ''
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                                                    zip join_trick
# 0                         [(Data Purposes, Data Uses)]
# 1    [(Personalisation of Ads, Content and Services...
# 2    [(Optimization of Ads, Content and Services , ...
# 3    [(Marketing , Subscription-Data Marketing: Ena...
# 4    [(Same as the previous data category, Same as ...
# ..                                                 ...        ...
# 250  [(No data collected from Vanity Fair (France) ...
# 251  [(No data collected from Vanity Fair (France) ...
# 252  [(No data collected from Vanity Fair (France) ...
# 253  [(No data collected from Vanity Fair (France) ...
# 254  [(No data collected from Vanity Fair (France) ...
#
# [255 rows x 5 columns]

# %%
df_merged_sample_zip.iloc[1,1]
# Out:
# 'Databricks'

# %%
[s for s in ['Sames as f*',''] if 'Same' in s]
# Out:
# ['Sames as f*']

# %%
[i for i in df_merged_sample_zip.iloc[4,2][0]]
# Out:
# ['A']

# %%
[s for s in df_merged_sample_zip.iloc[4,2][0] if 'Same' in s]
# Out:
# []

# %%
for r in range(0, len(df_merged_sample_zip)):
  #print(df_merged_sample_zip.iloc[r,2])

  if df_merged_sample_zip.iloc[r,3] == [('', '')] \
    or df_merged_sample_zip.iloc[r,3] == [('Same as the previous data category', 'Same as the previous data category')] \
    or len([s for s in df_merged_sample_zip.iloc[r,3][0]  if 'Same as' in s])>0 \
    or len([s for s in df_merged_sample_zip.iloc[r,3][0]  if 'same as' in s])>0 :


    anc = df_merged_sample_zip.iloc[r-1,2]
    #print(anc)
    new=df_merged_sample_zip.iloc[r-1,4]

    if len(df_merged_sample_zip.iloc[r-1,4])==0:
      df_merged_sample_zip.iloc[r,4] = anc
    else:
      df_merged_sample_zip.iloc[r,4] = new



  # else:
  #   new = df_merged_sample_zip.iloc[r,1]
  #   #print(anc)
  #   df_merged_sample_zip.iloc[r,3] = new

df_merged_sample_zip
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                                                    zip  \
# 0                         [(Data Purposes, Data Uses)]
# 1    [(Personalisation of Ads, Content and Services...
# 2    [(Optimization of Ads, Content and Services , ...
# 3    [(Marketing , Subscription-Data Marketing: Ena...
# 4    [(Same as the previous data category, Same as ...
# ..                                                 ...
# 250  [(No data collected from Vanity Fair (France) ...
# 251  [(No data collected from Vanity Fair (France) ...
# 252  [(No data collected from Vanity Fair (France) ...
# 253  [(No data collected from Vanity Fair (France) ...
# 254  [(No data collected from Vanity Fair (France) ...
#
#                                join_trick
# 0
# 1
# 2
# 3
# 4    User Browsing & Engagement Behaviour
# ..                                    ...
# 250
# 251
# 252
# 253
# 254
#
# [255 rows x 5 columns]

# %%
df_merged_sample_zip[df_merged_sample_zip['join_trick']=='']
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 12                                     Falcon
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 12                                     SocialFlow
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 12                User Browsing & Engagement Behaviour
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                                                    zip join_trick
# 0                         [(Data Purposes, Data Uses)]
# 1    [(Personalisation of Ads, Content and Services...
# 2    [(Optimization of Ads, Content and Services , ...
# 3    [(Marketing , Subscription-Data Marketing: Ena...
# 12   [(Personalisation of Ads, Content and Services...
# ..                                                 ...        ...
# 250  [(No data collected from Vanity Fair (France) ...
# 251  [(No data collected from Vanity Fair (France) ...
# 252  [(No data collected from Vanity Fair (France) ...
# 253  [(No data collected from Vanity Fair (France) ...
# 254  [(No data collected from Vanity Fair (France) ...
#
# [160 rows x 5 columns]

# %%
df_merged_sample_zip_same = pd.merge(df_merged_sample_zip, df_merged_sample_zip, how='inner',
                                     left_on=['System', 'Sources', 'join_trick'], right_on=['System','Sources', 'Data_Category'] )

df_merged_sample_zip_same = df_merged_sample_zip_same[['System','Sources','Data_Category_x','zip_y','join_trick_x']]

df_merged_sample_zip_same.columns = ['System', 'Sources','Data_Category','zip','join_trick']

df_merged_sample_zip_same
# Out:
#           System            Sources                    Data_Category  \
# 0    Qlik + Dash         Databricks             Audience Measurement
# 1    Qlik + Dash         Databricks             Audience Measurement
# 2    Qlik + Dash         Databricks             Audience Measurement
# 3    Qlik + Dash         Databricks     Advertising Performance Data
# 4    Qlik + Dash         Databricks     Advertising Performance Data
# ..           ...                ...                              ...
# 241       OB/Tag  Google Ad Manager  Video Views and Engagement Data
# 242       OB/Tag  Google Ad Manager  Video Views and Engagement Data
# 243       OB/Tag  Google Ad Manager    Mobile Device Management Data
# 244       OB/Tag  Google Ad Manager    Mobile Device Management Data
# 245       OB/Tag  Google Ad Manager    Mobile Device Management Data
#
#                                                    zip  \
# 0    [(Personalisation of Ads, Content and Services...
# 1    [(Optimization of Ads, Content and Services , ...
# 2    [(Marketing , Subscription-Data Marketing: Ena...
# 3    [(Personalisation of Ads, Content and Services...
# 4    [(Optimization of Ads, Content and Services , ...
# ..                                                 ...
# 241  [(Personalisation of Ads, Content and Services...
# 242  [(Optimization of Ads, Content and Services , ...
# 243  [(Technical provision of a requested product o...
# 244  [(Personalisation of Ads, Content and Services...
# 245  [(Optimization of Ads, Content and Services , ...
#
#                                join_trick
# 0    User Browsing & Engagement Behaviour
# 1    User Browsing & Engagement Behaviour
# 2    User Browsing & Engagement Behaviour
# 3    User Browsing & Engagement Behaviour
# 4    User Browsing & Engagement Behaviour
# ..                                    ...
# 241  User Browsing & Engagement Behaviour
# 242  User Browsing & Engagement Behaviour
# 243  User Browsing & Engagement Behaviour
# 244  User Browsing & Engagement Behaviour
# 245  User Browsing & Engagement Behaviour
#
# [246 rows x 5 columns]

# %%
df_merged_sample_zip_fin = pd.concat([
    df_merged_sample_zip[df_merged_sample_zip['join_trick']==''],
    df_merged_sample_zip_same], ignore_index=True)

df_merged_sample_zip_fin
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                      Falcon
# ..                                        ...
# 401                                    OB/Tag
# 402                                    OB/Tag
# 403                                    OB/Tag
# 404                                    OB/Tag
# 405                                    OB/Tag
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      SocialFlow
# ..                                            ...
# 401                             Google Ad Manager
# 402                             Google Ad Manager
# 403                             Google Ad Manager
# 404                             Google Ad Manager
# 405                             Google Ad Manager
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                 User Browsing & Engagement Behaviour
# ..                                                 ...
# 401                    Video Views and Engagement Data
# 402                    Video Views and Engagement Data
# 403                      Mobile Device Management Data
# 404                      Mobile Device Management Data
# 405                      Mobile Device Management Data
#
#                                                    zip  \
# 0                         [(Data Purposes, Data Uses)]
# 1    [(Personalisation of Ads, Content and Services...
# 2    [(Optimization of Ads, Content and Services , ...
# 3    [(Marketing , Subscription-Data Marketing: Ena...
# 4    [(Personalisation of Ads, Content and Services...
# ..                                                 ...
# 401  [(Personalisation of Ads, Content and Services...
# 402  [(Optimization of Ads, Content and Services , ...
# 403  [(Technical provision of a requested product o...
# 404  [(Personalisation of Ads, Content and Services...
# 405  [(Optimization of Ads, Content and Services , ...
#
#                                join_trick
# 0
# 1
# 2
# 3
# 4
# ..                                    ...
# 401  User Browsing & Engagement Behaviour
# 402  User Browsing & Engagement Behaviour
# 403  User Browsing & Engagement Behaviour
# 404  User Browsing & Engagement Behaviour
# 405  User Browsing & Engagement Behaviour
#
# [406 rows x 5 columns]

# %%
df_merged_sample_zip_fin_explode = df_merged_sample_zip_fin[['System','Sources','Data_Category','zip']].explode('zip')

df_merged_sample_zip_fin_explode
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 1                                 Qlik + Dash
# 1                                 Qlik + Dash
# 1                                 Qlik + Dash
# ..                                        ...
# 405                                    OB/Tag
# 405                                    OB/Tag
# 405                                    OB/Tag
# 405                                    OB/Tag
# 405                                    OB/Tag
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 1                                      Databricks
# 1                                      Databricks
# 1                                      Databricks
# ..                                            ...
# 405                             Google Ad Manager
# 405                             Google Ad Manager
# 405                             Google Ad Manager
# 405                             Google Ad Manager
# 405                             Google Ad Manager
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 1                 User Browsing & Engagement Behaviour
# 1                 User Browsing & Engagement Behaviour
# 1                 User Browsing & Engagement Behaviour
# ..                                                 ...
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
#
#                                                    zip
# 0                           (Data Purposes, Data Uses)
# 1    (Personalisation of Ads, Content and Services ...
# 1    (Personalisation of Ads, Content and Services ...
# 1    (Personalisation of Ads, Content and Services ...
# 1    (Personalisation of Ads, Content and Services ...
# ..                                                 ...
# 405  (Optimization of Ads, Content and Services , P...
# 405  (Optimization of Ads, Content and Services , C...
# 405  (Optimization of Ads, Content and Services , C...
# 405  (Optimization of Ads, Content and Services , S...
# 405  (Optimization of Ads, Content and Services , R...
#
# [1937 rows x 4 columns]

# %%
df_merged_sample_zip_fin_explode['Data_Purpose'] = df_merged_sample_zip_fin_explode['zip'].apply(lambda x: x[0] )

df_merged_sample_zip_fin_explode['Data_Uses'] = df_merged_sample_zip_fin_explode['zip'].apply(lambda x: x[1] )

df_merged_sample_zip_fin_explode
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 1                                 Qlik + Dash
# 1                                 Qlik + Dash
# 1                                 Qlik + Dash
# ..                                        ...
# 405                                    OB/Tag
# 405                                    OB/Tag
# 405                                    OB/Tag
# 405                                    OB/Tag
# 405                                    OB/Tag
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 1                                      Databricks
# 1                                      Databricks
# 1                                      Databricks
# ..                                            ...
# 405                             Google Ad Manager
# 405                             Google Ad Manager
# 405                             Google Ad Manager
# 405                             Google Ad Manager
# 405                             Google Ad Manager
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 1                 User Browsing & Engagement Behaviour
# 1                 User Browsing & Engagement Behaviour
# 1                 User Browsing & Engagement Behaviour
# ..                                                 ...
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
#
#                                                    zip  \
# 0                           (Data Purposes, Data Uses)
# 1    (Personalisation of Ads, Content and Services ...
# 1    (Personalisation of Ads, Content and Services ...
# 1    (Personalisation of Ads, Content and Services ...
# 1    (Personalisation of Ads, Content and Services ...
# ..                                                 ...
# 405  (Optimization of Ads, Content and Services , P...
# 405  (Optimization of Ads, Content and Services , C...
# 405  (Optimization of Ads, Content and Services , C...
# 405  (Optimization of Ads, Content and Services , S...
# 405  (Optimization of Ads, Content and Services , R...
#
#                                       Data_Purpose  \
# 0                                    Data Purposes
# 1    Personalisation of Ads, Content and Services
# 1    Personalisation of Ads, Content and Services
# 1    Personalisation of Ads, Content and Services
# 1    Personalisation of Ads, Content and Services
# ..                                             ...
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
#
#                                              Data_Uses
# 0                                            Data Uses
# 1    Content Personalisation: Tracking user prefere...
# 1    Personalised Advertising: Using the informatio...
# 1    Personalised Offers: using the information abo...
# 1    Personalised Ad Tracking: Tracking user intera...
# ..                                                 ...
# 405  Personalised Ad Performance Optimization: Moni...
# 405  Contextual Advertising : Analysing the webpage...
# 405  Contextual Ad Performance Optimization: Monito...
# 405  Screen Size: Detecting screen viewport size to...
# 405  Referral Source: Identifying whether users arr...
#
# [1937 rows x 6 columns]

# %%
df_final = df_merged_sample_zip_fin_explode[['System','Sources','Data_Category','Data_Purpose','Data_Uses']]

df_final
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 1                                 Qlik + Dash
# 1                                 Qlik + Dash
# 1                                 Qlik + Dash
# ..                                        ...
# 405                                    OB/Tag
# 405                                    OB/Tag
# 405                                    OB/Tag
# 405                                    OB/Tag
# 405                                    OB/Tag
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 1                                      Databricks
# 1                                      Databricks
# 1                                      Databricks
# ..                                            ...
# 405                             Google Ad Manager
# 405                             Google Ad Manager
# 405                             Google Ad Manager
# 405                             Google Ad Manager
# 405                             Google Ad Manager
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 1                 User Browsing & Engagement Behaviour
# 1                 User Browsing & Engagement Behaviour
# 1                 User Browsing & Engagement Behaviour
# ..                                                 ...
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
# 405                      Mobile Device Management Data
#
#                                       Data_Purpose  \
# 0                                    Data Purposes
# 1    Personalisation of Ads, Content and Services
# 1    Personalisation of Ads, Content and Services
# 1    Personalisation of Ads, Content and Services
# 1    Personalisation of Ads, Content and Services
# ..                                             ...
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
#
#                                              Data_Uses
# 0                                            Data Uses
# 1    Content Personalisation: Tracking user prefere...
# 1    Personalised Advertising: Using the informatio...
# 1    Personalised Offers: using the information abo...
# 1    Personalised Ad Tracking: Tracking user intera...
# ..                                                 ...
# 405  Personalised Ad Performance Optimization: Moni...
# 405  Contextual Advertising : Analysing the webpage...
# 405  Contextual Ad Performance Optimization: Monito...
# 405  Screen Size: Detecting screen viewport size to...
# 405  Referral Source: Identifying whether users arr...
#
# [1937 rows x 5 columns]

# %%
len(df_final)
# Out:
# 1937

# %%
df_final = df_final[1:]

# %%
df_final.groupby(['System','Sources']).size()
# Out:
# System             Sources
# 4D                 ContentIQ                   5
#                    Snowplow                    5
# AWS                Databricks                  1
# Acpm.fr            Facebook + other pixels     2
# AdmantX            ContentIQ                   9
#                                               ..
# Verso              Fastly                      1
#                    Website (Vanity Fair FR)    1
# Youtube            Website (Vanity Fair FR     1
# dbt Labs           Databricks (meta data)      1
# xid (infinity id)  N/A                         7
# Length: 68, dtype: int64

# %%
df_final
# Out:
#           System            Sources                         Data_Category  \
# 1    Qlik + Dash         Databricks  User Browsing & Engagement Behaviour
# 1    Qlik + Dash         Databricks  User Browsing & Engagement Behaviour
# 1    Qlik + Dash         Databricks  User Browsing & Engagement Behaviour
# 1    Qlik + Dash         Databricks  User Browsing & Engagement Behaviour
# 1    Qlik + Dash         Databricks  User Browsing & Engagement Behaviour
# ..           ...                ...                                   ...
# 405       OB/Tag  Google Ad Manager         Mobile Device Management Data
# 405       OB/Tag  Google Ad Manager         Mobile Device Management Data
# 405       OB/Tag  Google Ad Manager         Mobile Device Management Data
# 405       OB/Tag  Google Ad Manager         Mobile Device Management Data
# 405       OB/Tag  Google Ad Manager         Mobile Device Management Data
#
#                                       Data_Purpose  \
# 1    Personalisation of Ads, Content and Services
# 1    Personalisation of Ads, Content and Services
# 1    Personalisation of Ads, Content and Services
# 1    Personalisation of Ads, Content and Services
# 1    Personalisation of Ads, Content and Services
# ..                                             ...
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
# 405     Optimization of Ads, Content and Services
#
#                                              Data_Uses
# 1    Content Personalisation: Tracking user prefere...
# 1    Personalised Advertising: Using the informatio...
# 1    Personalised Offers: using the information abo...
# 1    Personalised Ad Tracking: Tracking user intera...
# 1    Conversion Rate Analysis: Analysing conversion...
# ..                                                 ...
# 405  Personalised Ad Performance Optimization: Moni...
# 405  Contextual Advertising : Analysing the webpage...
# 405  Contextual Ad Performance Optimization: Monito...
# 405  Screen Size: Detecting screen viewport size to...
# 405  Referral Source: Identifying whether users arr...
#
# [1936 rows x 5 columns]

# %%
len(df_final)
# Out:
# 1936

# %%
import gsheet_pandas
from gspread_dataframe import set_with_dataframe

try:
  worksheet = gsheets.add_worksheet(title="Automated_ROPA", rows=10000, cols=20)
except:
  print('worksheet exists')

# select a work sheet from its name
worksheet1 = gsheets.worksheet('Automated_ROPA')

# write to dataframe
worksheet1.clear()
set_with_dataframe(worksheet=worksheet1, dataframe=df_final, include_index=False,
include_column_header=True, resize=True)

print('data written length: ' + str(len(df_final)))
# Out:
# data written length: 1936

# %%
len(df_final)
# Out:
# 1936

# %%
len(df_final[df_final.duplicated()])
# Out:
# 1

# %%
1800-401
# Out:
# 1399

# %%
df_infos
# Out:
#                                   Acquisition  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                                         \
# 0                                          Description
# 1    Data visualization tool: creating interactive ...
# 2    Data visualization tool: creating interactive ...
# 3    Data visualization tool: creating interactive ...
# 4    Data visualization tool: creating interactive ...
# ..                                                 ...
# 250  GAM is a software owned by Google used by CN f...
# 251  GAM is a software owned by Google used by CN f...
# 252  GAM is a software owned by Google used by CN f...
# 253  GAM is a software owned by Google used by CN f...
# 254  ACPM (The Alliance for Print and Media Data) i...
#
#                                              \
# 0    Internal or Third Party  Internal Team
# 1                       3rdP     Technology
# 2                       3rdP     Technology
# 3                       3rdP     Technology
# 4                       3rdP     Technology
# ..                       ...            ...
# 250                       3P     Technology
# 251                       3P     Technology
# 252                       3P     Technology
# 253                       3P     Technology
# 254                       3P      Marketing
#
#                                                         \
# 0                         Owners/Stakeholders/Contacts
# 1                                Prasannaa Subramanian
# 2                                Prasannaa Subramanian
# 3                                Prasannaa Subramanian
# 4                                Prasannaa Subramanian
# ..                                                 ...
# 250  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 251  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 252  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 253  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 254  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
#
#                                                    \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                                       \
# 0    Connection type between the source and the tool
# 1                                  Native connection
# 2                                  Native connection
# 3                                  Native connection
# 4                                  Native connection
# ..                                               ...
# 250                                          GTM Tag
# 251                                          GTM Tag
# 252                                          GTM Tag
# 253                                          GTM Tag
# 254                                          GTM Tag
#
#                                                         \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                                                \
# 0                     Data Collection Methods
# 1          Collected directly from Databricks
# 2          Collected directly from Databricks
# 3          Collected directly from Databricks
# 4          Collected directly from Databricks
# ..                                        ...
# 250  Collected directly from Social Platforms
# 251  Collected directly from Social Platforms
# 252  Collected directly from Social Platforms
# 253  Collected directly from Social Platforms
# 254  Collected directly from Social Platforms
#
#                                                 ...  \
# 0    Data Collection adapted to user consent?   ...
# 1                                            Y  ...
# 2                                            Y  ...
# 3                                            Y  ...
# 4                                            Y  ...
# ..                                         ...  ...
# 250                                        Yes  ...
# 251                                        Yes  ...
# 252                                        Yes  ...
# 253                                        Yes  ...
# 254                                        Yes  ...
#
#                                            \
# 0    Data shared overseas -\nY, where | N
# 1                                     N/A
# 2                                     N/A
# 3                                     N/A
# 4                                     N/A
# ..                                    ...
# 250                                   N/A
# 251                                   N/A
# 252                                   N/A
# 253                                   N/A
# 254                                   N/A
#
#                                           \
# 0    Data encryption or pseudonymisation
# 1                                    N/A
# 2                                    N/A
# 3                                    N/A
# 4                                    N/A
# ..                                   ...
# 250                                  N/A
# 251                                  N/A
# 252                                  N/A
# 253                                  N/A
# 254                                  N/A
#
#                                   Retention & Disposal  \
# 0    Duration for which the data is required to rem...
# 1       2 years (mostly)  - It can be 4 but never more
# 2       2 years (mostly)  - It can be 4 but never more
# 3       2 years (mostly)  - It can be 4 but never more
# 4       2 years (mostly)  - It can be 4 but never more
# ..                                                 ...
# 250                                                N/A
# 251                                                N/A
# 252                                                N/A
# 253                                                N/A
# 254                                                N/A
#
#                                                      \
# 0       Duration for which the data is retained\n\n
# 1    2 years (mostly)  - It can be 4 but never more
# 2    2 years (mostly)  - It can be 4 but never more
# 3    2 years (mostly)  - It can be 4 but never more
# 4    2 years (mostly)  - It can be 4 but never more
# ..                                              ...
# 250                                             N/A
# 251                                             N/A
# 252                                             N/A
# 253                                             N/A
# 254                                             N/A
#
#                                                         \
# 0    Policies and processes for retaining and delet...
# 1                                                    Y
# 2                                                    Y
# 3                                                    Y
# 4                                                    Y
# ..                                                 ...
# 250                                                N/A
# 251                                                N/A
# 252                                                N/A
# 253                                                N/A
# 254                                                N/A
#
#                                                                      Access  \
# 0    Methods to ensure that deleted data is removed...  Doc shared with B&S
# 1    Only on the plateform, not on Databricks\n\nAu...                    Y
# 2    Only on the plateform, not on Databricks\n\nAu...                    Y
# 3    Only on the plateform, not on Databricks\n\nAu...                    Y
# 4    Only on the plateform, not on Databricks\n\nAu...                    Y
# ..                                                 ...                  ...
# 250                                                N/A                    N
# 251                                                N/A                    N
# 252                                                N/A                    N
# 253                                                N/A                    N
# 254                                                N/A                    N
#
#
# 0
# 1
# 2
# 3
# 4
# ..  .. ..  ...
# 250        N/A
# 251        N/A
# 252        N/A
# 253        N/A
# 254        N/A
#
# [255 rows x 36 columns]

# %%
info_columns = ['System',
                'Description',
                'Internal or 3rd Party',
                'Internal Team',
                'Owners',
                'Sources',
                'Connection',
                'Data_Category',
                'Data Collection',
                'Consent',
                'Tracker',
                'Data_Purpose',
                'Data_Uses',
                'France',
                'ePrivacy',
                'Store System',
                '3rd Party Provider',
                'Juridiction Region',
                'Restrictions',
                'Tech Orga Measures',
                'Data Shared',
                'Which company sharing',
                'Another tool system',
                'Which Recipient',
                'Sharing Purpose',
                'Sharing Methods',
                'Overseas',
                'Encryption',
                'Rentention Duration Original',
                'Retention Duration Retain',
                'Retention Policies',
                'Methods Delete',
                'Access B&S',
                '1',
                '2',
                '3'
                ]

# %%
df_infos.columns = info_columns

df_infos
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                            Description  \
# 0                                          Description
# 1    Data visualization tool: creating interactive ...
# 2    Data visualization tool: creating interactive ...
# 3    Data visualization tool: creating interactive ...
# 4    Data visualization tool: creating interactive ...
# ..                                                 ...
# 250  GAM is a software owned by Google used by CN f...
# 251  GAM is a software owned by Google used by CN f...
# 252  GAM is a software owned by Google used by CN f...
# 253  GAM is a software owned by Google used by CN f...
# 254  ACPM (The Alliance for Print and Media Data) i...
#
#        Internal or 3rd Party  Internal Team  \
# 0    Internal or Third Party  Internal Team
# 1                       3rdP     Technology
# 2                       3rdP     Technology
# 3                       3rdP     Technology
# 4                       3rdP     Technology
# ..                       ...            ...
# 250                       3P     Technology
# 251                       3P     Technology
# 252                       3P     Technology
# 253                       3P     Technology
# 254                       3P      Marketing
#
#                                                 Owners  \
# 0                         Owners/Stakeholders/Contacts
# 1                                Prasannaa Subramanian
# 2                                Prasannaa Subramanian
# 3                                Prasannaa Subramanian
# 4                                Prasannaa Subramanian
# ..                                                 ...
# 250  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 251  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 252  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 253  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 254  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                           Connection  \
# 0    Connection type between the source and the tool
# 1                                  Native connection
# 2                                  Native connection
# 3                                  Native connection
# 4                                  Native connection
# ..                                               ...
# 250                                          GTM Tag
# 251                                          GTM Tag
# 252                                          GTM Tag
# 253                                          GTM Tag
# 254                                          GTM Tag
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                               Data Collection  \
# 0                     Data Collection Methods
# 1          Collected directly from Databricks
# 2          Collected directly from Databricks
# 3          Collected directly from Databricks
# 4          Collected directly from Databricks
# ..                                        ...
# 250  Collected directly from Social Platforms
# 251  Collected directly from Social Platforms
# 252  Collected directly from Social Platforms
# 253  Collected directly from Social Platforms
# 254  Collected directly from Social Platforms
#
#                                        Consent  ...  \
# 0    Data Collection adapted to user consent?   ...
# 1                                            Y  ...
# 2                                            Y  ...
# 3                                            Y  ...
# 4                                            Y  ...
# ..                                         ...  ...
# 250                                        Yes  ...
# 251                                        Yes  ...
# 252                                        Yes  ...
# 253                                        Yes  ...
# 254                                        Yes  ...
#
#                                  Overseas  \
# 0    Data shared overseas -\nY, where | N
# 1                                     N/A
# 2                                     N/A
# 3                                     N/A
# 4                                     N/A
# ..                                    ...
# 250                                   N/A
# 251                                   N/A
# 252                                   N/A
# 253                                   N/A
# 254                                   N/A
#
#                               Encryption  \
# 0    Data encryption or pseudonymisation
# 1                                    N/A
# 2                                    N/A
# 3                                    N/A
# 4                                    N/A
# ..                                   ...
# 250                                  N/A
# 251                                  N/A
# 252                                  N/A
# 253                                  N/A
# 254                                  N/A
#
#                           Rentention Duration Original  \
# 0    Duration for which the data is required to rem...
# 1       2 years (mostly)  - It can be 4 but never more
# 2       2 years (mostly)  - It can be 4 but never more
# 3       2 years (mostly)  - It can be 4 but never more
# 4       2 years (mostly)  - It can be 4 but never more
# ..                                                 ...
# 250                                                N/A
# 251                                                N/A
# 252                                                N/A
# 253                                                N/A
# 254                                                N/A
#
#                           Retention Duration Retain  \
# 0       Duration for which the data is retained\n\n
# 1    2 years (mostly)  - It can be 4 but never more
# 2    2 years (mostly)  - It can be 4 but never more
# 3    2 years (mostly)  - It can be 4 but never more
# 4    2 years (mostly)  - It can be 4 but never more
# ..                                              ...
# 250                                             N/A
# 251                                             N/A
# 252                                             N/A
# 253                                             N/A
# 254                                             N/A
#
#                                     Retention Policies  \
# 0    Policies and processes for retaining and delet...
# 1                                                    Y
# 2                                                    Y
# 3                                                    Y
# 4                                                    Y
# ..                                                 ...
# 250                                                N/A
# 251                                                N/A
# 252                                                N/A
# 253                                                N/A
# 254                                                N/A
#
#                                         Methods Delete           Access B&S  \
# 0    Methods to ensure that deleted data is removed...  Doc shared with B&S
# 1    Only on the plateform, not on Databricks\n\nAu...                    Y
# 2    Only on the plateform, not on Databricks\n\nAu...                    Y
# 3    Only on the plateform, not on Databricks\n\nAu...                    Y
# 4    Only on the plateform, not on Databricks\n\nAu...                    Y
# ..                                                 ...                  ...
# 250                                                N/A                    N
# 251                                                N/A                    N
# 252                                                N/A                    N
# 253                                                N/A                    N
# 254                                                N/A                    N
#
#     1  2     3
# 0
# 1
# 2
# 3
# 4
# ..  .. ..  ...
# 250        N/A
# 251        N/A
# 252        N/A
# 253        N/A
# 254        N/A
#
# [255 rows x 36 columns]

# %%
df_infos.iloc[0, :]
# Out:
# System                                   The name of the tool / provider / system
# Description                                                           Description
# Internal or 3rd Party                                     Internal or Third Party
# Internal Team                                                       Internal Team
# Owners                                               Owners/Stakeholders/Contacts
# Sources                              Source(s) from which the tool retrieves data
# Connection                        Connection type between the source and the tool
# Data_Category                   Data Categories gathered from the source(s) \n...
# Data Collection                                           Data Collection Methods
# Consent                                 Data Collection adapted to user consent?
# Tracker                         Tracker? (network calls from users to the syst...
# Data_Purpose                                                        Data Purposes
# Data_Uses                                                               Data Uses
# France                                                   Data processed for VF FR
# ePrivacy                        ePrivacy Application: Are there network calls ...
# Store System                    What system do we store that data in (when it ...
# 3rd Party Provider                               Who is the third party provider?
# Juridiction Region              What jurisdiction / geographic region is this ...
# Restrictions                    Restrictions / Limitations concerning the stor...
# Tech Orga Measures                             Technical Organisational Measures
# Data Shared                                   Data shared with other CN entities?
# Which company sharing                                          If yes, which ones
# Another tool system                      Data shared with another tool / system ?
# Which Recipient                                         If yes, which recipients?
# Sharing Purpose                                          Purpose for sharing data
# Sharing Methods                                                   Sharing methods
# Overseas                                     Data shared overseas -\nY, where | N
# Encryption                                    Data encryption or pseudonymisation
# Rentention Duration Original    Duration for which the data is required to rem...
# Retention Duration Retain             Duration for which the data is retained\n\n
# Retention Policies              Policies and processes for retaining and delet...
# Methods Delete                  Methods to ensure that deleted data is removed...
# Access B&S                                                    Doc shared with B&S
# 1
# 2
# 3
# Name: 0, dtype: object

# %%
for i in range(0,len(df_infos)):
  for c in range(0,len(df_infos.columns)):
    #print(c)
    z = df_infos.iloc[i, c]
    if z == '':
      df_infos.iloc[i, c] = df_infos.iloc[i-1, c]

df_infos#.iloc[:, 0].unique().tolist()
# Out:
#                                        System  \
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 2                                 Qlik + Dash
# 3                                 Qlik + Dash
# 4                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
#                                            Description  \
# 0                                          Description
# 1    Data visualization tool: creating interactive ...
# 2    Data visualization tool: creating interactive ...
# 3    Data visualization tool: creating interactive ...
# 4    Data visualization tool: creating interactive ...
# ..                                                 ...
# 250  GAM is a software owned by Google used by CN f...
# 251  GAM is a software owned by Google used by CN f...
# 252  GAM is a software owned by Google used by CN f...
# 253  GAM is a software owned by Google used by CN f...
# 254  ACPM (The Alliance for Print and Media Data) i...
#
#        Internal or 3rd Party  Internal Team  \
# 0    Internal or Third Party  Internal Team
# 1                       3rdP     Technology
# 2                       3rdP     Technology
# 3                       3rdP     Technology
# 4                       3rdP     Technology
# ..                       ...            ...
# 250                       3P     Technology
# 251                       3P     Technology
# 252                       3P     Technology
# 253                       3P     Technology
# 254                       3P      Marketing
#
#                                                 Owners  \
# 0                         Owners/Stakeholders/Contacts
# 1                                Prasannaa Subramanian
# 2                                Prasannaa Subramanian
# 3                                Prasannaa Subramanian
# 4                                Prasannaa Subramanian
# ..                                                 ...
# 250  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 251  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 252  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 253  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
# 254  Anthony Torres\nTess Shapiro\nBrooke Edwards P...
#
#                                           Sources  \
# 0    Source(s) from which the tool retrieves data
# 1                                      Databricks
# 2                                      Databricks
# 3                                      Databricks
# 4                                      Databricks
# ..                                            ...
# 250                                     Permutive
# 251                                           IAS
# 252                                          MOAT
# 253                       Facebook + other pixels
# 254                       Facebook + other pixels
#
#                                           Connection  \
# 0    Connection type between the source and the tool
# 1                                  Native connection
# 2                                  Native connection
# 3                                  Native connection
# 4                                  Native connection
# ..                                               ...
# 250                                          GTM Tag
# 251                                          GTM Tag
# 252                                          GTM Tag
# 253                                          GTM Tag
# 254                                          GTM Tag
#
#                                          Data_Category  \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2                 User Browsing & Engagement Behaviour
# 3                 User Browsing & Engagement Behaviour
# 4                                 Audience Measurement
# ..                                                 ...
# 250                      All Permutive Data Categories
# 251                      All Permutive Data Categories
# 252                      All Permutive Data Categories
# 253                      All Permutive Data Categories
# 254                      All Permutive Data Categories
#
#                               Data Collection  \
# 0                     Data Collection Methods
# 1          Collected directly from Databricks
# 2          Collected directly from Databricks
# 3          Collected directly from Databricks
# 4          Collected directly from Databricks
# ..                                        ...
# 250  Collected directly from Social Platforms
# 251  Collected directly from Social Platforms
# 252  Collected directly from Social Platforms
# 253  Collected directly from Social Platforms
# 254  Collected directly from Social Platforms
#
#                                        Consent  ...  \
# 0    Data Collection adapted to user consent?   ...
# 1                                            Y  ...
# 2                                            Y  ...
# 3                                            Y  ...
# 4                                            Y  ...
# ..                                         ...  ...
# 250                                        Yes  ...
# 251                                        Yes  ...
# 252                                        Yes  ...
# 253                                        Yes  ...
# 254                                        Yes  ...
#
#                                  Overseas  \
# 0    Data shared overseas -\nY, where | N
# 1                                     N/A
# 2                                     N/A
# 3                                     N/A
# 4                                     N/A
# ..                                    ...
# 250                                   N/A
# 251                                   N/A
# 252                                   N/A
# 253                                   N/A
# 254                                   N/A
#
#                               Encryption  \
# 0    Data encryption or pseudonymisation
# 1                                    N/A
# 2                                    N/A
# 3                                    N/A
# 4                                    N/A
# ..                                   ...
# 250                                  N/A
# 251                                  N/A
# 252                                  N/A
# 253                                  N/A
# 254                                  N/A
#
#                           Rentention Duration Original  \
# 0    Duration for which the data is required to rem...
# 1       2 years (mostly)  - It can be 4 but never more
# 2       2 years (mostly)  - It can be 4 but never more
# 3       2 years (mostly)  - It can be 4 but never more
# 4       2 years (mostly)  - It can be 4 but never more
# ..                                                 ...
# 250                                                N/A
# 251                                                N/A
# 252                                                N/A
# 253                                                N/A
# 254                                                N/A
#
#                           Retention Duration Retain  \
# 0       Duration for which the data is retained\n\n
# 1    2 years (mostly)  - It can be 4 but never more
# 2    2 years (mostly)  - It can be 4 but never more
# 3    2 years (mostly)  - It can be 4 but never more
# 4    2 years (mostly)  - It can be 4 but never more
# ..                                              ...
# 250                                             N/A
# 251                                             N/A
# 252                                             N/A
# 253                                             N/A
# 254                                             N/A
#
#                                     Retention Policies  \
# 0    Policies and processes for retaining and delet...
# 1                                                    Y
# 2                                                    Y
# 3                                                    Y
# 4                                                    Y
# ..                                                 ...
# 250                                                N/A
# 251                                                N/A
# 252                                                N/A
# 253                                                N/A
# 254                                                N/A
#
#                                         Methods Delete           Access B&S  \
# 0    Methods to ensure that deleted data is removed...  Doc shared with B&S
# 1    Only on the plateform, not on Databricks\n\nAu...                    Y
# 2    Only on the plateform, not on Databricks\n\nAu...                    Y
# 3    Only on the plateform, not on Databricks\n\nAu...                    Y
# 4    Only on the plateform, not on Databricks\n\nAu...                    Y
# ..                                                 ...                  ...
# 250                                                N/A                    N
# 251                                                N/A                    N
# 252                                                N/A                    N
# 253                                                N/A                    N
# 254                                                N/A                    N
#
#     1  2     3
# 0          N/A
# 1          N/A
# 2          N/A
# 3          N/A
# 4          N/A
# ..  .. ..  ...
# 250        N/A
# 251        N/A
# 252        N/A
# 253        N/A
# 254        N/A
#
# [255 rows x 36 columns]

# %%
len(df_final)
# Out:
# 1936

# %%
len(df_infos)
# Out:
# 255

# %%
df_infos.columns
# Out:
# Index(['System', 'Description', 'Internal or 3rd Party', 'Internal Team',
#        'Owners', 'Sources', 'Connection', 'Data_Category', 'Data Collection',
#        'Consent', 'Tracker', 'Data_Purpose', 'Data_Uses', 'France', 'ePrivacy',
#        'Store System', '3rd Party Provider', 'Juridiction Region',
#        'Restrictions', 'Tech Orga Measures', 'Data Shared',
#        'Which company sharing', 'Another tool system', 'Which Recipient',
#        'Sharing Purpose', 'Sharing Methods', 'Overseas', 'Encryption',
#        'Rentention Duration Original', 'Retention Duration Retain',
#        'Retention Policies', 'Methods Delete', 'Access B&S', '1', '2', '3'],
#       dtype='object')

# %%
df_infos[df_infos['System']=='System K']
# Out:
# Empty DataFrame
# Columns: [System, Description, Internal or 3rd Party, Internal Team, Owners, Sources, Connection, Data_Category, Data Collection, Consent, Tracker, Data_Purpose, Data_Uses, France, ePrivacy, Store System, 3rd Party Provider, Juridiction Region, Restrictions, Tech Orga Measures, Data Shared, Which company sharing, Another tool system, Which Recipient, Sharing Purpose, Sharing Methods, Overseas, Encryption, Rentention Duration Original, Retention Duration Retain, Retention Policies, Methods Delete, Access B&S, 1, 2, 3]
# Index: []
#
# [0 rows x 36 columns]

# %%
df_infos_unique = df_infos[['System', 'Description', 'Internal or 3rd Party', 'Internal Team',
       'Owners', 'Sources', 'Connection',
                            'Data_Category',
                  'Data Collection',
       'Consent', 'Tracker',
                            #'Data_Purpose', 'Data_Uses',
              'France', 'ePrivacy',
       'Store System', '3rd Party Provider', 'Juridiction Region',
       'Restrictions', 'Tech Orga Measures', 'Data Shared',
       'Which company sharing', 'Another tool system', 'Which Recipient',
       'Sharing Purpose', 'Sharing Methods', 'Overseas', 'Encryption',
       'Rentention Duration Original', 'Retention Duration Retain',
       'Retention Policies', 'Methods Delete', 'Access B&S']]

df_infos_unique = df_infos_unique.drop_duplicates()

len(df_infos_unique)
# Out:
# 224

# %%
df_infos_unique[['System']]
# Out:
#                                        System
# 0    The name of the tool / provider / system
# 1                                 Qlik + Dash
# 4                                 Qlik + Dash
# 5                                 Qlik + Dash
# 6                                 Qlik + Dash
# ..                                        ...
# 250                         Google Ad Manager
# 251                         Google Ad Manager
# 252                         Google Ad Manager
# 253                         Google Ad Manager
# 254                                   Acpm.fr
#
# [224 rows x 1 columns]

# %%
#df1.merge(df2, on='column_name', how='left')
df_final_merged = pd.merge(df_final,df_infos_unique,how='left',on=['System','Sources','Data_Category'] , validate = 'm:1' )  ### , validate = 'm:1'

df_final_merged.columns = [x[:-2] if any(k in x for k in ['_x']) else x for x in df_final_merged.columns]  ### remove _x

df_final_merged = df_final_merged.reset_index()
df_final_merged = df_final_merged.drop_duplicates()

df_final_merged[(df_final_merged['System']=='System I') & (df_final_merged['Data_Category']=='User Identifiers')
 & (df_final_merged['Data_Uses']=='Personalised Ad Performance Optimization: Monitoring the effectiveness of advertising campaigns by tracking ad impressions, clicks, conversions, and other relevant metrics to optimize targeting and messaging.')]
# Out:
# Empty DataFrame
# Columns: [index, System, Sources, Data_Category, Data_Purpose, Data_Uses, Description, Internal or 3rd Party, Internal Team, Owners, Connection, Data Collection, Consent, Tracker, France, ePrivacy, Store System, 3rd Party Provider, Juridiction Region, Restrictions, Tech Orga Measures, Data Shared, Which company sharing, Another tool system, Which Recipient, Sharing Purpose, Sharing Methods, Overseas, Encryption, Rentention Duration Original, Retention Duration Retain, Retention Policies, Methods Delete, Access B&S]
# Index: []
#
# [0 rows x 34 columns]

# %%
len(df_final_merged)
# Out:
# 1936

# %%
final_ropa_columns_info = [

  'Data_Category',  #1	Data Category

  #2	Data Type   >>>tab Category
  #3	Data Subjects >>>tab Category
  'Data Collection', #4	Data Collection Methods >>>tab Collection

  'System', #5	Tool that collects the Data -- System?????

  'Internal or 3rd Party', #6	Internal or Third Party
  'Internal Team',  #7	Team managing the tool
  'Sources', #8	Source from which the tool retrieves data
  'Consent',#9	Consent to collect this data

  #10	What is the Agreement related to this collection - LEGAL ONLY
  #11	Legal Basis for Collection LEGAL ONLY
  #12	Privacy Policy - disclosure category LEGAL ONLY

  'Data_Purpose',#13	Data Purpose
  'Data_Uses',#14	Data Use
  #15	Legal Basis for Use LEGAL ONLY
  'Store System',#16	What system do we store that data in (when it is in our possession)?
  '3rd Party Provider',#17	Who is the third party provider?
  'Juridiction Region',#18	What jurisdiction / geographic region is this data stored in?

  'Retention Duration Retain',#19	What is the retention period? ??????????????????

  #20	What Agreement do we store the data under? LEGAL ONLY

  'Data Shared',#21	Do we share this data with other BRAND entities?
  'Which company sharing',#22	If yes, list the entities

  'Which Recipient', #23	Who do we share this data with (ie what tool / system)?   ??????

  'Sharing Methods',#24	How do we share the data with the recipient?   ?????

  'Restrictions',#25	Do we limit the sharing or use techniques to limit the sharing of personal information with this third party?

  #26	Did we share it overseas?
  #27	If yes, where is the recipient located?

  'Tech Orga Measures', #28	What technical organisational measures do we have in place? (See TOMs and please put the corresponding numbers)

  #29	What Agreement do we share the data under? LEGAL ONLY

  ### AS DISCUSSED STOP HERE ALL SYSTEM IN 1 COLUMNS ONLY

  #30	Who do we share the data with (ie what entity)?
  #31	What is the purpose for sharing the data with that entity?
  #32	How do we share the data with the recipient?
  #33	Did we share it overseas?
  #34	If yes, where is the recipient located?
  #35	What technical organisational measures do we have in place? (See TOMs and please put the corresponding numbers)
  #36	What Agreement do we share the data under? LEGAL ONLY
  #37	Who do we share the data with (ie what entity)?
  #38	What is the purpose for sharing the data with that entity?
  #39	How do we share the data with the recipient?
  #40	Did we share it overseas?
  #41	If yes, where is the recipient located?
  #42	What technical organisational measures do we have in place? (See TOMs and please put the corresponding numbers)
  #43	What Agreement do we share the data under? LEGAL ONLY
]

# %%
df_final_merged_ropa_col = df_final_merged[final_ropa_columns_info]

df_final_merged_ropa_col = df_final_merged_ropa_col.loc[1:]

df_final_merged_ropa_col
# Out:
#                              Data_Category  \
# 1     User Browsing & Engagement Behaviour
# 2     User Browsing & Engagement Behaviour
# 3     User Browsing & Engagement Behaviour
# 4     User Browsing & Engagement Behaviour
# 5     User Browsing & Engagement Behaviour
# ...                                    ...
# 1931         Mobile Device Management Data
# 1932         Mobile Device Management Data
# 1933         Mobile Device Management Data
# 1934         Mobile Device Management Data
# 1935         Mobile Device Management Data
#
#                                 Data Collection       System  \
# 1            Collected directly from Databricks  Qlik + Dash
# 2            Collected directly from Databricks  Qlik + Dash
# 3            Collected directly from Databricks  Qlik + Dash
# 4            Collected directly from Databricks  Qlik + Dash
# 5            Collected directly from Databricks  Qlik + Dash
# ...                                         ...          ...
# 1931  Collected directly from Google Ad Manager       OB/Tag
# 1932  Collected directly from Google Ad Manager       OB/Tag
# 1933  Collected directly from Google Ad Manager       OB/Tag
# 1934  Collected directly from Google Ad Manager       OB/Tag
# 1935  Collected directly from Google Ad Manager       OB/Tag
#
#      Internal or 3rd Party       Internal Team            Sources Consent  \
# 1                     3rdP          Technology         Databricks       Y
# 2                     3rdP          Technology         Databricks       Y
# 3                     3rdP          Technology         Databricks       Y
# 4                     3rdP          Technology         Databricks       Y
# 5                     3rdP          Technology         Databricks       Y
# ...                    ...                 ...                ...     ...
# 1931                  3rdP  Commercial Revenue  Google Ad Manager       Y
# 1932                  3rdP  Commercial Revenue  Google Ad Manager       Y
# 1933                  3rdP  Commercial Revenue  Google Ad Manager       Y
# 1934                  3rdP  Commercial Revenue  Google Ad Manager       Y
# 1935                  3rdP  Commercial Revenue  Google Ad Manager       Y
#
#                                        Data_Purpose  \
# 1     Personalisation of Ads, Content and Services
# 2     Personalisation of Ads, Content and Services
# 3     Personalisation of Ads, Content and Services
# 4     Personalisation of Ads, Content and Services
# 5        Optimization of Ads, Content and Services
# ...                                             ...
# 1931     Optimization of Ads, Content and Services
# 1932     Optimization of Ads, Content and Services
# 1933     Optimization of Ads, Content and Services
# 1934     Optimization of Ads, Content and Services
# 1935     Optimization of Ads, Content and Services
#
#                                               Data_Uses       Store System  \
# 1     Personalised Advertising: Using the informatio...         Databricks
# 2     Personalised Offers: using the information abo...         Databricks
# 3     Personalised Ad Tracking: Tracking user intera...         Databricks
# 4     Conversion Rate Analysis: Analysing conversion...         Databricks
# 5     Personalised Ad Performance Optimization: Moni...         Databricks
# ...                                                 ...                ...
# 1931  Personalised Ad Performance Optimization: Moni...  Google Ad Manager
# 1932  Contextual Advertising : Analysing the webpage...  Google Ad Manager
# 1933  Contextual Ad Performance Optimization: Monito...  Google Ad Manager
# 1934  Screen Size: Detecting screen viewport size to...  Google Ad Manager
# 1935  Referral Source: Identifying whether users arr...  Google Ad Manager
#
#      3rd Party Provider                                 Juridiction Region  \
# 1             Amazon S3  Access in edit mode: eng team US \n\nAccess in...
# 2             Amazon S3  Access in edit mode: eng team US \n\nAccess in...
# 3             Amazon S3  Access in edit mode: eng team US \n\nAccess in...
# 4             Amazon S3  Access in edit mode: eng team US \n\nAccess in...
# 5             Amazon S3  Access in edit mode: eng team US \n\nAccess in...
# ...                 ...                                                ...
# 1931             Google                          Same as Google Ad Manager
# 1932             Google                          Same as Google Ad Manager
# 1933             Google                          Same as Google Ad Manager
# 1934             Google                          Same as Google Ad Manager
# 1935             Google                          Same as Google Ad Manager
#
#                            Retention Duration Retain Data Shared  \
# 1     2 years (mostly)  - It can be 4 but never more           Y
# 2     2 years (mostly)  - It can be 4 but never more           Y
# 3     2 years (mostly)  - It can be 4 but never more           Y
# 4     2 years (mostly)  - It can be 4 but never more           Y
# 5     2 years (mostly)  - It can be 4 but never more           Y
# ...                                              ...         ...
# 1931                       Same as Google Ad Manager           Y
# 1932                       Same as Google Ad Manager           Y
# 1933                       Same as Google Ad Manager           Y
# 1934                       Same as Google Ad Manager           Y
# 1935                       Same as Google Ad Manager           Y
#
#                        Which company sharing            Which Recipient  \
# 1                                All of them                        N/A
# 2                                All of them                        N/A
# 3                                All of them                        N/A
# 4                                All of them                        N/A
# 5                                All of them                        N/A
# ...                                      ...                        ...
# 1931  All people with Google AdManger Access  OB/Tag partners\n\nAdomik
# 1932  All people with Google AdManger Access  OB/Tag partners\n\nAdomik
# 1933  All people with Google AdManger Access  OB/Tag partners\n\nAdomik
# 1934  All people with Google AdManger Access  OB/Tag partners\n\nAdomik
# 1935  All people with Google AdManger Access  OB/Tag partners\n\nAdomik
#
#                                         Sharing Methods  \
# 1                                                   N/A
# 2                                                   N/A
# 3                                                   N/A
# 4                                                   N/A
# 5                                                   N/A
# ...                                                 ...
# 1931  OB/Tag partners: Native Integration\n\nAdomik:...
# 1932  OB/Tag partners: Native Integration\n\nAdomik:...
# 1933  OB/Tag partners: Native Integration\n\nAdomik:...
# 1934  OB/Tag partners: Native Integration\n\nAdomik:...
# 1935  OB/Tag partners: Native Integration\n\nAdomik:...
#
#                                            Restrictions  \
# 1     Data is always aggregated in reporting / BI to...
# 2     Data is always aggregated in reporting / BI to...
# 3     Data is always aggregated in reporting / BI to...
# 4     Data is always aggregated in reporting / BI to...
# 5     Data is always aggregated in reporting / BI to...
# ...                                                 ...
# 1931                          Same as Google Ad Manager
# 1932                          Same as Google Ad Manager
# 1933                          Same as Google Ad Manager
# 1934                          Same as Google Ad Manager
# 1935                          Same as Google Ad Manager
#
#                                      Tech Orga Measures
# 1     2, 4, 5, 6, 7, 9, 10, 12, 15, 16, 18, 21, 24, ...
# 2     2, 4, 5, 6, 7, 9, 10, 12, 15, 16, 18, 21, 24, ...
# 3     2, 4, 5, 6, 7, 9, 10, 12, 15, 16, 18, 21, 24, ...
# 4     2, 4, 5, 6, 7, 9, 10, 12, 15, 16, 18, 21, 24, ...
# 5     2, 4, 5, 6, 7, 9, 10, 12, 15, 16, 18, 21, 24, ...
# ...                                                 ...
# 1931                          Same as Google Ad Manager
# 1932                          Same as Google Ad Manager
# 1933                          Same as Google Ad Manager
# 1934                          Same as Google Ad Manager
# 1935                          Same as Google Ad Manager
#
# [1935 rows x 19 columns]

# %%
len(df_final_merged_ropa_col)
# Out:
# 1935

# %%
### Final ROPA columns

#1	Data Category

#2	Data Type   >>>tab Category
#3	Data Subjects >>>tab Category
#4	Data Collection Methods >>>tab Collection

#5	Tool that collects the Data -- System?????

#6	Internal or Third Party
#7	Team managing the tool
#8	Source from which the tool retrieves data
#9	Consent to collect this data
#10	What is the Agreement related to this collection - LEGAL ONLY
#11	Legal Basis for Collection LEGAL ONLY
#12	Privacy Policy - disclosure category LEGAL ONLY
#13	Data Purpose
#14	Data Use
#15	Legal Basis for Use LEGAL ONLY
#16	What system do we store that data in (when it is in our possession)?
#17	Who is the third party provider?
#18	What jurisdiction / geographic region is this data stored in?
#19	What is the retention period?
#20	What Agreement do we store the data under? LEGAL ONLY
#21	Do we share this data with other BRAND entities?
#22	If yes, list the entities
#23	Who do we share this data with (ie what tool / system)?
#24	How do we share the data with the recipient?
#25	Do we limit the sharing or use techniques to limit the sharing of personal information with this third party?
#26	Did we share it overseas?
#27	If yes, where is the recipient located?
#28	What technical organisational measures do we have in place? (See TOMs and please put the corresponding numbers)
#29	What Agreement do we share the data under? LEGAL ONLY
#30	Who do we share the data with (ie what entity)?
#31	What is the purpose for sharing the data with that entity?
#32	How do we share the data with the recipient?
#33	Did we share it overseas?
#34	If yes, where is the recipient located?
#35	What technical organisational measures do we have in place? (See TOMs and please put the corresponding numbers)
#36	What Agreement do we share the data under? LEGAL ONLY
#37	Who do we share the data with (ie what entity)?
#38	What is the purpose for sharing the data with that entity?
#39	How do we share the data with the recipient?
#40	Did we share it overseas?
#41	If yes, where is the recipient located?
#42	What technical organisational measures do we have in place? (See TOMs and please put the corresponding numbers)
#43	What Agreement do we share the data under? LEGAL ONLY

# %%
### df_merged_sample_zip_same.columns = [x[:-2] if any(k in x for k in ['_x']) else x for x in df_merged_sample_zip_same.columns]  ### remove _x
