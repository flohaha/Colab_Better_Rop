# %% [markdown]
# <a href="https://colab.research.google.com/github/flohaha/Colab_Better_Rop/blob/main/ROPA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install google
#!pip install google-api-core
#!pip install google-colab
#!pip install gspread

# %%
import gspread

# %%
try:
    from google.colab import auth
    auth.authenticate_user()

    from oauth2client.client import GoogleCredentials

except:
    print('couldnt connect')
# Out:
# couldnt connect

# %%
 try:
    from google.colab import drive
    drive.mount('/content/drive')
    #!ls -l /content/drive/'My Drive/PRO/BetterStronger/ROPA'
except:
    print('couldnt connect')
# Out:
# couldnt connect

# %%
#from google.colab import auth
#auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In [13], line 6
#       4 import gspread
#       5 from google.auth import default
# ----> 6 creds, _ = default()
#       8 gc = gspread.authorize(creds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\google\auth\_default.py:691, in default(scopes, request, quota_project_id, default_scopes)
#     683             _LOGGER.warning(
#     684                 "No project ID could be determined. Consider running "
#     685                 "`gcloud config set project` or setting the %s "
#     686                 "environment variable",
#     687                 environment_vars.PROJECT,
#     688             )
#     689         return credentials, effective_project_id
# --> 691 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %%
SS_Link = 'https://docs.google.com/spreadsheets/d/18kI721X-bXSx-nnOjzGuPM62buTsfiMsEDc7sEIciWI/edit#gid=957651562'

# %%
import pandas as pd
# read data and put it in a dataframe
gsheets = gc.open_by_url(SS_Link)
sheets = gsheets.worksheet('Data Infos').get_all_values()
df_infos = pd.DataFrame(sheets[1:], columns=sheets[0])

df_infos
# Out:
#                                   Acquisition  \
# 0    The name of the tool / provider / system
# 1                                    System A
# 2
# 3
# 4
# ..                                        ...
# 108
# 109
# 110
# 111                                  System K
# 112
#
#                                                         \
# 0                                          Description
# 1    First-party customer behavioral event tracking...
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111  The platform delivers real-time context about ...
# 112
#
#                                                                            \
# 0    Internal or Third Party  Internal Team  Owners/Stakeholders/Contacts
# 1                       1stP     Technology             Owner of System A
# 2
# 3
# 4
# ..                       ...            ...                           ...
# 108
# 109
# 110
# 111                     1stP     Technology             Owner of System K
# 112
#
#                                                    \
# 0    Source(s) from which the tool retrieves data
# 1                                         Website
# 2
# 3
# 4
# ..                                            ...
# 108
# 109
# 110
# 111                                      System X
# 112                                      System Z
#
#                                                       \
# 0    Connection type between the source and the tool
# 1                                 Internet protocols
# 2
# 3
# 4
# ..                                               ...
# 108
# 109
# 110
# 111                                              API
# 112                                              API
#
#                                                         \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2
# 3
# 4
# ..                                                 ...
# 108                                      User Segments
# 109                    Video Views and Engagement Data
# 110                      Mobile Device Management Data
# 111               All System A post consent categories
# 112               All System B post consent categories
#
#                                        \
# 0             Data Collection Methods
# 1                     Cookies\nPixels
# 2
# 3
# 4
# ..                                ...
# 108
# 109
# 110
# 111  Collected directly from System A
# 112  Collected directly from System B
#
#                                                 ...  \
# 0    Data Collection adapted to user consent?   ...
# 1                                            Y  ...
# 2                                               ...
# 3                                               ...
# 4                                               ...
# ..                                         ...  ...
# 108                                             ...
# 109                                             ...
# 110                                             ...
# 111                                          Y  ...
# 112                    N/A (Content Meta Data)  ...
#
#                                                           \
# 0    If yes, which recipients?  Purpose for sharing data
# 1                  Recipient E     Same as data purposes
# 2
# 3
# 4
# ..                         ...                       ...
# 108
# 109
# 110
# 111                        N/A                       N/A
# 112
#
#                                       \
# 0                    Sharing methods
# 1    It is shared via data warehouse
# 2
# 3
# 4
# ..                               ...
# 108
# 109
# 110
# 111                              N/A
# 112
#
#                                                         \
# 0                 Data shared overseas -\nY, where | N
# 1    The data is shared in all markets where our bu...
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111                              Data stored in the US
# 112
#
#                                           \
# 0    Data encryption or pseudonymisation
# 1                                      Y
# 2
# 3
# 4
# ..                                   ...
# 108
# 109
# 110
# 111                                    N
# 112
#
#                                   Retention & Disposal  \
# 0    Duration for which the data is required to rem...
# 1    The data in its original form is not required ...
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111                                            30 days
# 112
#
#                                                         \
# 0          Duration for which the data is retained\n\n
# 1    This is determined in the data warehouse and n...
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111                                            30 days
# 112
#
#                                                         \
# 0    Policies and processes for retaining and delet...
# 1                 The data is not retained by Snowplow
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111                                                  Y
# 112
#
#                                                                      Access
# 0    Methods to ensure that deleted data is removed...  Doc shared with B&S
# 1                                                                         Y
# 2
# 3
# 4
# ..                                                 ...                  ...
# 108
# 109
# 110
# 111                                        Auto delete                    Y
# 112
#
# [113 rows x 33 columns]

# %%
# col_names = df_infos.iloc[1:3, :]

# df_infos.reset_index(drop=True, inplace=True)

df_infos.iloc[0, :]

#df_infos.columns #= df_infos.iloc[0:1, :]
# Out:
# Acquisition                      The name of the tool / provider / system
#                                                               Description
#                                                   Internal or Third Party
#                                                             Internal Team
#                                              Owners/Stakeholders/Contacts
#                              Source(s) from which the tool retrieves data
#                           Connection type between the source and the tool
#                         Data Categories gathered from the source(s) \n...
#                                                   Data Collection Methods
#                                 Data Collection adapted to user consent?
#                         Tracker? (network calls from users to the syst...
# Processing                                                  Data Purposes
#                                                                 Data Uses
#                                                 Data processed in France?
#                         ePrivacy Application: Are there network calls ...
# Storage                 What system do we store that data in (when it ...
#                                          Who is the third party provider?
#                         What jurisdiction / geographic region is this ...
#                         Restrictions / Limitations concerning the stor...
#                                        Technical Organisational Measures
# Sharing                   Data shared with other entities in the Comapny?
#                                                        If yes, which ones
#                                  Data shared with another tool / system ?
#                                                 If yes, which recipients?
#                                                  Purpose for sharing data
#                                                           Sharing methods
#                                      Data shared overseas -\nY, where | N
#                                       Data encryption or pseudonymisation
# Retention & Disposal    Duration for which the data is required to rem...
#                               Duration for which the data is retained\n\n
#                         Policies and processes for retaining and delet...
#                         Methods to ensure that deleted data is removed...
# Access                                                Doc shared with B&S
# Name: 0, dtype: object

# %%
len(df_infos)
# Out:
# 113

# %%
df_infos.iloc[:, 0].unique().tolist()
# Out:
# ['The name of the tool / provider / system',
#  'System A',
#  '',
#  'System B',
#  'System C',
#  'System D',
#  'System E',
#  'System Y',
#  'System Z',
#  'System F',
#  'System G',
#  'System H',
#  'System I',
#  'System J',
#  'System K']

# %%
for i in range(0,len(df_infos)):
  z = df_infos.iloc[i, 0]
  if z == '':
    df_infos.iloc[i, 0] = df_infos.iloc[i-1, 0]

df_infos#.iloc[:, 0].unique().tolist()
# Out:
#                                   Acquisition  \
# 0    The name of the tool / provider / system
# 1                                    System A
# 2                                    System A
# 3                                    System A
# 4                                    System A
# ..                                        ...
# 108                                  System J
# 109                                  System J
# 110                                  System J
# 111                                  System K
# 112                                  System K
#
#                                                         \
# 0                                          Description
# 1    First-party customer behavioral event tracking...
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111  The platform delivers real-time context about ...
# 112
#
#                                                                            \
# 0    Internal or Third Party  Internal Team  Owners/Stakeholders/Contacts
# 1                       1stP     Technology             Owner of System A
# 2
# 3
# 4
# ..                       ...            ...                           ...
# 108
# 109
# 110
# 111                     1stP     Technology             Owner of System K
# 112
#
#                                                    \
# 0    Source(s) from which the tool retrieves data
# 1                                         Website
# 2
# 3
# 4
# ..                                            ...
# 108
# 109
# 110
# 111                                      System X
# 112                                      System Z
#
#                                                       \
# 0    Connection type between the source and the tool
# 1                                 Internet protocols
# 2
# 3
# 4
# ..                                               ...
# 108
# 109
# 110
# 111                                              API
# 112                                              API
#
#                                                         \
# 0    Data Categories gathered from the source(s) \n...
# 1                 User Browsing & Engagement Behaviour
# 2
# 3
# 4
# ..                                                 ...
# 108                                      User Segments
# 109                    Video Views and Engagement Data
# 110                      Mobile Device Management Data
# 111               All System A post consent categories
# 112               All System B post consent categories
#
#                                        \
# 0             Data Collection Methods
# 1                     Cookies\nPixels
# 2
# 3
# 4
# ..                                ...
# 108
# 109
# 110
# 111  Collected directly from System A
# 112  Collected directly from System B
#
#                                                 ...  \
# 0    Data Collection adapted to user consent?   ...
# 1                                            Y  ...
# 2                                               ...
# 3                                               ...
# 4                                               ...
# ..                                         ...  ...
# 108                                             ...
# 109                                             ...
# 110                                             ...
# 111                                          Y  ...
# 112                    N/A (Content Meta Data)  ...
#
#                                                           \
# 0    If yes, which recipients?  Purpose for sharing data
# 1                  Recipient E     Same as data purposes
# 2
# 3
# 4
# ..                         ...                       ...
# 108
# 109
# 110
# 111                        N/A                       N/A
# 112
#
#                                       \
# 0                    Sharing methods
# 1    It is shared via data warehouse
# 2
# 3
# 4
# ..                               ...
# 108
# 109
# 110
# 111                              N/A
# 112
#
#                                                         \
# 0                 Data shared overseas -\nY, where | N
# 1    The data is shared in all markets where our bu...
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111                              Data stored in the US
# 112
#
#                                           \
# 0    Data encryption or pseudonymisation
# 1                                      Y
# 2
# 3
# 4
# ..                                   ...
# 108
# 109
# 110
# 111                                    N
# 112
#
#                                   Retention & Disposal  \
# 0    Duration for which the data is required to rem...
# 1    The data in its original form is not required ...
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111                                            30 days
# 112
#
#                                                         \
# 0          Duration for which the data is retained\n\n
# 1    This is determined in the data warehouse and n...
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111                                            30 days
# 112
#
#                                                         \
# 0    Policies and processes for retaining and delet...
# 1                 The data is not retained by Snowplow
# 2
# 3
# 4
# ..                                                 ...
# 108
# 109
# 110
# 111                                                  Y
# 112
#
#                                                                      Access
# 0    Methods to ensure that deleted data is removed...  Doc shared with B&S
# 1                                                                         Y
# 2
# 3
# 4
# ..                                                 ...                  ...
# 108
# 109
# 110
# 111                                        Auto delete                    Y
# 112
#
# [113 rows x 33 columns]

# %%
df_sample = df_infos[df_infos.iloc[:, 0] == 'System I']

df_sample = df_sample.iloc[:, [0,7,11,12]]#,14,19]]

df_sample
# Out:
#     Acquisition                                        \
# 93     System I  User Browsing & Engagement Behaviour
# 94     System I
# 95     System I
# 96     System I             User Tracking Identifiers
# 97     System I                      User Identifiers
# 98     System I                      Content Metadata
# 99     System I          Advertising Performance Data
# 100    System I                         User Segments
#
#                                             Processing  \
# 93   Technical provision of a requested product or ...
# 94       Personalisation of Ads, Content and Services
# 95          Optimization of Ads, Content and Services
# 96                  Same as the previous data category
# 97
# 98
# 99
# 100
#
#
# 93   Ad-Network Integration (Contextual): Integrati...
# 94   Personalised Advertising: Using the informatio...
# 95   Personalised Ad Performance Optimization: Moni...
# 96                  Same as the previous data category
# 97
# 98
# 99
# 100

# %%
df_sample.columns = ['System','Data_Category','Data_Purpose','Data_Uses']#,'','']

# %%
df_sample

for i in range(0,len(df_sample)):
  z = df_sample.iloc[i, 1]
  if z == '':
    df_sample.iloc[i, 1] = df_sample.iloc[i-1, 1]

df_sample#.iloc[:, 0].unique().tolist()
# Out:
#        System                         Data_Category  \
# 93   System I  User Browsing & Engagement Behaviour
# 94   System I  User Browsing & Engagement Behaviour
# 95   System I  User Browsing & Engagement Behaviour
# 96   System I             User Tracking Identifiers
# 97   System I                      User Identifiers
# 98   System I                      Content Metadata
# 99   System I          Advertising Performance Data
# 100  System I                         User Segments
#
#                                           Data_Purpose  \
# 93   Technical provision of a requested product or ...
# 94       Personalisation of Ads, Content and Services
# 95          Optimization of Ads, Content and Services
# 96                  Same as the previous data category
# 97
# 98
# 99
# 100
#
#                                              Data_Uses
# 93   Ad-Network Integration (Contextual): Integrati...
# 94   Personalised Advertising: Using the informatio...
# 95   Personalised Ad Performance Optimization: Moni...
# 96                  Same as the previous data category
# 97
# 98
# 99
# 100

# %%
df_sample_gp = df_sample.groupby(['System', 'Data_Category'])['Data_Purpose'].apply('||'.join).reset_index()

df_sample_gp
# Out:
#      System                         Data_Category  \
# 0  System I          Advertising Performance Data
# 1  System I                      Content Metadata
# 2  System I  User Browsing & Engagement Behaviour
# 3  System I                      User Identifiers
# 4  System I                         User Segments
# 5  System I             User Tracking Identifiers
#
#                                         Data_Purpose
# 0
# 1
# 2  Technical provision of a requested product or ...
# 3
# 4
# 5                 Same as the previous data category

# %%
df_sample_unique = df_sample[['System','Data_Category']].drop_duplicates()

df_sample_unique
# Out:
#        System                         Data_Category
# 93   System I  User Browsing & Engagement Behaviour
# 96   System I             User Tracking Identifiers
# 97   System I                      User Identifiers
# 98   System I                      Content Metadata
# 99   System I          Advertising Performance Data
# 100  System I                         User Segments

# %%
df_merged = pd.merge(df_sample_unique, df_sample_gp, how='left', left_on=['System', 'Data_Category'], right_on=['System', 'Data_Category'] )

df_merged = pd.merge(df_merged, df_sample, how='left', left_on=['System', 'Data_Category'], right_on=['System', 'Data_Category'] )


#df_merged['System','Data_Category','Data_Purpose_y','Data_Uses']

df_merged = df_merged[['System','Data_Category','Data_Purpose_y','Data_Uses']]
df_merged
# Out:
#      System                         Data_Category  \
# 0  System I  User Browsing & Engagement Behaviour
# 1  System I  User Browsing & Engagement Behaviour
# 2  System I  User Browsing & Engagement Behaviour
# 3  System I             User Tracking Identifiers
# 4  System I                      User Identifiers
# 5  System I                      Content Metadata
# 6  System I          Advertising Performance Data
# 7  System I                         User Segments
#
#                                       Data_Purpose_y  \
# 0  Technical provision of a requested product or ...
# 1      Personalisation of Ads, Content and Services
# 2         Optimization of Ads, Content and Services
# 3                 Same as the previous data category
# 4
# 5
# 6
# 7
#
#                                            Data_Uses
# 0  Ad-Network Integration (Contextual): Integrati...
# 1  Personalised Advertising: Using the informatio...
# 2  Personalised Ad Performance Optimization: Moni...
# 3                 Same as the previous data category
# 4
# 5
# 6
# 7

# %%
df_merged.iloc[1,[2,3]]
# Out:
# Data_Purpose_y        Personalisation of Ads, Content and Services
# Data_Uses         Personalised Advertising: Using the informatio...
# Name: 1, dtype: object

# %%
df_merged_sample = df_merged

df_merged_sample['Data_Uses'] = df_merged_sample['Data_Uses'].apply(lambda x: x.replace("\n","||"))

df_merged_sample['Data_Uses'] = df_merged_sample['Data_Uses'].apply(lambda x: x.split('||'))
df_merged_sample['Data_Purpose_y'] = df_merged_sample['Data_Purpose_y'].apply(lambda x: x.split('||'))

df_merged_sample
# Out:
#      System                         Data_Category  \
# 0  System I  User Browsing & Engagement Behaviour
# 1  System I  User Browsing & Engagement Behaviour
# 2  System I  User Browsing & Engagement Behaviour
# 3  System I             User Tracking Identifiers
# 4  System I                      User Identifiers
# 5  System I                      Content Metadata
# 6  System I          Advertising Performance Data
# 7  System I                         User Segments
#
#                                       Data_Purpose_y  \
# 0  [Technical provision of a requested product or...
# 1    [Personalisation of Ads, Content and Services ]
# 2       [Optimization of Ads, Content and Services ]
# 3               [Same as the previous data category]
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
#
#                                            Data_Uses
# 0  [Ad-Network Integration (Contextual): Integrat...
# 1  [Personalised Advertising: Using the informati...
# 2  [Personalised Ad Performance Optimization: Mon...
# 3               [Same as the previous data category]
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []

# %%
def product(*args):
    if not args:
        return iter(((),)) # yield tuple()
    return (items + (item,)
            for items in product(*args[:-1]) for item in args[-1])

list(product([1,2,3], ['a','b']))
# Out:
# [(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b'), (3, 'a'), (3, 'b')]

# %%
import itertools

somelists = [['aaz','bbz'],['ccz','ddz']]

list(itertools.product(['aa','bb'],['cc','dd']))
# Out:
# [('aa', 'cc'), ('aa', 'dd'), ('bb', 'cc'), ('bb', 'dd')]

# %%
df_merged_sample_zip = df_merged_sample

df_merged_sample_zip['zip'] = df_merged_sample_zip.apply(lambda x: list(product(x['Data_Purpose_y'], list(x['Data_Uses']))), axis=1)

df_merged_sample_zip = df_merged_sample_zip[['System','Data_Category','zip']]

df_merged_sample_zip
# Out:
#      System                         Data_Category  \
# 0  System I  User Browsing & Engagement Behaviour
# 1  System I  User Browsing & Engagement Behaviour
# 2  System I  User Browsing & Engagement Behaviour
# 3  System I             User Tracking Identifiers
# 4  System I                      User Identifiers
# 5  System I                      Content Metadata
# 6  System I          Advertising Performance Data
# 7  System I                         User Segments
#
#                                                  zip
# 0  [(Technical provision of a requested product o...
# 1  [(Personalisation of Ads, Content and Services...
# 2  [(Optimization of Ads, Content and Services , ...
# 3  [(Same as the previous data category, Same as ...
# 4                                             [(, )]
# 5                                             [(, )]
# 6                                             [(, )]
# 7                                             [(, )]

# %%
df_merged_sample_zip['join_trick'] = ''
df_merged_sample_zip
# Out:
# <ipython-input-21-b6fd350c56c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merged_sample_zip['join_trick'] = ''
#      System                         Data_Category  \
# 0  System I  User Browsing & Engagement Behaviour
# 1  System I  User Browsing & Engagement Behaviour
# 2  System I  User Browsing & Engagement Behaviour
# 3  System I             User Tracking Identifiers
# 4  System I                      User Identifiers
# 5  System I                      Content Metadata
# 6  System I          Advertising Performance Data
# 7  System I                         User Segments
#
#                                                  zip join_trick
# 0  [(Technical provision of a requested product o...
# 1  [(Personalisation of Ads, Content and Services...
# 2  [(Optimization of Ads, Content and Services , ...
# 3  [(Same as the previous data category, Same as ...
# 4                                             [(, )]
# 5                                             [(, )]
# 6                                             [(, )]
# 7                                             [(, )]

# %%
df_merged_sample_zip.iloc[1,1]
# Out:
# 'User Browsing & Engagement Behaviour'

# %%
for r in range(0, len(df_merged_sample_zip)):
  #print(df_merged_sample_zip.iloc[r,2])

  if df_merged_sample_zip.iloc[r,2] == [('', '')] or df_merged_sample_zip.iloc[r,2] == [('Same as the previous data category', 'Same as the previous data category')]:
    #print('ok')
    anc = df_merged_sample_zip.iloc[r-1,3]
    #print(anc)
    df_merged_sample_zip.iloc[r,3] = anc
  else:
    new = df_merged_sample_zip.iloc[r,1]
    #print(anc)
    df_merged_sample_zip.iloc[r,3] = new

df_merged_sample_zip
# Out:
#      System                         Data_Category  \
# 0  System I  User Browsing & Engagement Behaviour
# 1  System I  User Browsing & Engagement Behaviour
# 2  System I  User Browsing & Engagement Behaviour
# 3  System I             User Tracking Identifiers
# 4  System I                      User Identifiers
# 5  System I                      Content Metadata
# 6  System I          Advertising Performance Data
# 7  System I                         User Segments
#
#                                                  zip  \
# 0  [(Technical provision of a requested product o...
# 1  [(Personalisation of Ads, Content and Services...
# 2  [(Optimization of Ads, Content and Services , ...
# 3  [(Same as the previous data category, Same as ...
# 4                                             [(, )]
# 5                                             [(, )]
# 6                                             [(, )]
# 7                                             [(, )]
#
#                              join_trick
# 0  User Browsing & Engagement Behaviour
# 1  User Browsing & Engagement Behaviour
# 2  User Browsing & Engagement Behaviour
# 3  User Browsing & Engagement Behaviour
# 4  User Browsing & Engagement Behaviour
# 5  User Browsing & Engagement Behaviour
# 6  User Browsing & Engagement Behaviour
# 7  User Browsing & Engagement Behaviour

# %%
df_merged_sample_zip_fin = pd.merge(df_merged_sample_zip, df_merged_sample_zip, how='left', left_on=['System', 'join_trick'], right_on=['System', 'Data_Category'] )

df_merged_sample_zip_fin = df_merged_sample_zip_fin[['System','Data_Category_x','zip_y']]

df_merged_sample_zip_fin
# Out:
#       System                       Data_Category_x  \
# 0   System I  User Browsing & Engagement Behaviour
# 1   System I  User Browsing & Engagement Behaviour
# 2   System I  User Browsing & Engagement Behaviour
# 3   System I  User Browsing & Engagement Behaviour
# 4   System I  User Browsing & Engagement Behaviour
# 5   System I  User Browsing & Engagement Behaviour
# 6   System I  User Browsing & Engagement Behaviour
# 7   System I  User Browsing & Engagement Behaviour
# 8   System I  User Browsing & Engagement Behaviour
# 9   System I             User Tracking Identifiers
# 10  System I             User Tracking Identifiers
# 11  System I             User Tracking Identifiers
# 12  System I                      User Identifiers
# 13  System I                      User Identifiers
# 14  System I                      User Identifiers
# 15  System I                      Content Metadata
# 16  System I                      Content Metadata
# 17  System I                      Content Metadata
# 18  System I          Advertising Performance Data
# 19  System I          Advertising Performance Data
# 20  System I          Advertising Performance Data
# 21  System I                         User Segments
# 22  System I                         User Segments
# 23  System I                         User Segments
#
#                                                 zip_y
# 0   [(Technical provision of a requested product o...
# 1   [(Personalisation of Ads, Content and Services...
# 2   [(Optimization of Ads, Content and Services , ...
# 3   [(Technical provision of a requested product o...
# 4   [(Personalisation of Ads, Content and Services...
# 5   [(Optimization of Ads, Content and Services , ...
# 6   [(Technical provision of a requested product o...
# 7   [(Personalisation of Ads, Content and Services...
# 8   [(Optimization of Ads, Content and Services , ...
# 9   [(Technical provision of a requested product o...
# 10  [(Personalisation of Ads, Content and Services...
# 11  [(Optimization of Ads, Content and Services , ...
# 12  [(Technical provision of a requested product o...
# 13  [(Personalisation of Ads, Content and Services...
# 14  [(Optimization of Ads, Content and Services , ...
# 15  [(Technical provision of a requested product o...
# 16  [(Personalisation of Ads, Content and Services...
# 17  [(Optimization of Ads, Content and Services , ...
# 18  [(Technical provision of a requested product o...
# 19  [(Personalisation of Ads, Content and Services...
# 20  [(Optimization of Ads, Content and Services , ...
# 21  [(Technical provision of a requested product o...
# 22  [(Personalisation of Ads, Content and Services...
# 23  [(Optimization of Ads, Content and Services , ...

# %%
df_merged_sample_zip['zipst'] = df_merged_sample_zip['zip'].apply(lambda x: str(x))

df_merged_sample_zip = df_merged_sample_zip.groupby(['System', 'Data_Category'])['zipst'].apply('||'.join).reset_index()


df_merged_sample_zip
# Out:
#      System                         Data_Category  \
# 0  System I          Advertising Performance Data
# 1  System I                      Content Metadata
# 2  System I  User Browsing & Engagement Behaviour
# 3  System I                      User Identifiers
# 4  System I                         User Segments
# 5  System I             User Tracking Identifiers
#
#                                                zipst
# 0                                         [('', '')]
# 1                                         [('', '')]
# 2  [('Technical provision of a requested product ...
# 3                                         [('', '')]
# 4                                         [('', '')]
# 5  [('Same as the previous data category', 'Same ...

# %%
df_merged_sample_zip_fin = pd.merge(df_sample_unique, df_merged_sample_zip, how='left', left_on=['System', 'Data_Category'], right_on=['System', 'Data_Category'] )


df_merged_sample_zip_fin
# Out:
#      System                         Data_Category  \
# 0  System I  User Browsing & Engagement Behaviour
# 1  System I             User Tracking Identifiers
# 2  System I                      User Identifiers
# 3  System I                      Content Metadata
# 4  System I          Advertising Performance Data
# 5  System I                         User Segments
#
#                                                zipst
# 0  [('Technical provision of a requested product ...
# 1  [('Same as the previous data category', 'Same ...
# 2                                         [('', '')]
# 3                                         [('', '')]
# 4                                         [('', '')]
# 5                                         [('', '')]

# %%
df_merged_sample_zip_fin['zip_ok'] = df_merged_sample_zip_fin['zipst'].apply(lambda x: x.split('||'))
df_merged_sample_zip_fin
# Out:
#      System                         Data_Category  \
# 0  System I  User Browsing & Engagement Behaviour
# 1  System I             User Tracking Identifiers
# 2  System I                      User Identifiers
# 3  System I                      Content Metadata
# 4  System I          Advertising Performance Data
# 5  System I                         User Segments
#
#                                                zipst  \
# 0  [('Technical provision of a requested product ...
# 1  [('Same as the previous data category', 'Same ...
# 2                                         [('', '')]
# 3                                         [('', '')]
# 4                                         [('', '')]
# 5                                         [('', '')]
#
#                                               zip_ok
# 0  [[('Technical provision of a requested product...
# 1  [[('Same as the previous data category', 'Same...
# 2                                       [[('', '')]]
# 3                                       [[('', '')]]
# 4                                       [[('', '')]]
# 5                                       [[('', '')]]

# %%
ast.litteral((df_merged_sample_zip_fin.iloc[1, 3])[0]
# Out:
#   File "<ipython-input-28-87c47b377815>", line 1
#     ast.litteral((df_merged_sample_zip_fin.iloc[1, 3])[0]
#                                                          ^
# SyntaxError: incomplete input

# %%
for i in range(0,len(df_merged_sample_zip_fin)):
  z = df_merged_sample_zip_fin.iloc[i, 2]
  if z == [('', '')] or z== [('Same as the previous data category', 'Same as the previous data category')] :
    df_merged_sample_zip_fin.iloc[i, 2] = df_merged_sample_zip_fin.iloc[i-1, 2]


df_merged_sample_zip_fin#.iloc[:, 0].unique().tolist()

# %%
import json
df_merged_sample_zip_fin.iloc[3,2]
#l = json.loads(df_merged_sample_zip_fin.iloc[3,2])
#l

# %%
import ast

df_merged_sample_zip_fin['zip']= df_merged_sample_zip_fin['zipst'].apply(lambda x: ast.literal_eval(x))

df_merged_sample_zip_fin

# %%
df_merged_sample_zip_fin[df_merged_sample_zip_fin['Data_Category']=='User Browsing & Engagement Behaviour']

# %%
df_merged_sample_zip_fin[df_merged_sample_zip_fin['Data_Category']=='User Browsing & Engagement Behaviour'][['zipst']]

# %%
list(df_merged_sample_zip[df_merged_sample_zip['Data_Category']=='User Browsing & Engagement Behaviour']['zip'])[0]

# %%
list(df_merged_sample_zip[df_merged_sample_zip['Data_Category']=='User Browsing & Engagement Behaviour']['zip'])[1]

# %%
df_merged_sample_zip_explode = df_merged_sample_zip[['System','Data_Category','zip']].explode('zip')

df_merged_sample_zip_explode

# %%
len(df_merged_sample_zip_explode)

# %%
df_merged_sample_zip_explode['Data_Purpose_zip'] = df_merged_sample_zip_explode['zip'].apply(lambda x:x[0])
df_merged_sample_zip_explode['Data_Uses_zip'] = df_merged_sample_zip_explode['zip'].apply(lambda x:x[1])

df_merged_sample_zip_explode

# %%
df_merged_sample_zip_explode[df_merged_sample_zip_explode['Data_Purpose_zip']==df_merged_sample_zip_explode.iloc[0,3]]

# %%
worksheet = gsheets.add_worksheet(title="A New Automated worksheet", rows=100, cols=20)
